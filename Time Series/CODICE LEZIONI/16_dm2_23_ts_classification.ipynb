# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import defaultdict

# %% [markdown]
# # Data Preparation

# %%
from pyts.datasets import make_cylinder_bell_funnel

# %%
X, y = make_cylinder_bell_funnel(n_samples=1000, random_state=42)

# %%
plt.figure()
for i, classe in enumerate(['cylinder', 'bell', 'funnel']):
    plt.subplot(3, 1, i + 1)
    for x in X[y == i]:
        plt.plot(x, color='C0', linewidth=0.9)
    plt.title('Class: {}'.format(classe), fontsize=16)

plt.tight_layout()
plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
plt.plot(X[0])

# %% [markdown]
# # Data Normalization

# %%
from tslearn.preprocessing import TimeSeriesScalerMinMax

# %%
scaler = TimeSeriesScalerMinMax()
X = scaler.fit_transform(X).reshape(X.shape[0], X.shape[1])

# %% [markdown]
# # Data Partitioning

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %%
X_train.shape
# Out:
# (700, 128)

# %% [markdown]
# # Shaplet Classifiers

# %%
# Brute Force Approach

# %%
from pyts.transformation import ShapeletTransform

# %%
# Shapelet transformation
st = ShapeletTransform(window_sizes=[4, 12],
                       random_state=42, sort=True)
X_new = st.fit_transform(X_train, y_train)
X_test_new = st.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_new, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %%
# Learning-based Approach

# %%
from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

# %%
n_ts, ts_sz = X_train.shape
n_classes = len(set(y))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 700
# ts_sz 128
# n_classes 3
# shapelet_sizes {12: 5}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=200,
                        verbose=1)
# Out:
# /Users/riccardo/opt/miniconda3/lib/python3.8/site-packages/tslearn/shapelets/shapelets.py:354: FutureWarning: The default value for 'scale' is set to False in version 0.4 to ensure backward compatibility, but is likely to change in a future version.
#   warnings.warn("The default value for 'scale' is set to False "

# %%
shp_clf.fit(X_train, y_train)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1276 - categorical_accuracy: 0.3295 - categorical_crossentropy: 1.0967
# Epoch 2/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1277 - categorical_accuracy: 0.3241 - categorical_crossentropy: 1.0968
# Epoch 3/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1274 - categorical_accuracy: 0.3295 - categorical_crossentropy: 1.0965
# Epoch 4/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1272 - categorical_accuracy: 0.3310 - categorical_crossentropy: 1.0964
# Epoch 5/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1279 - categorical_accuracy: 0.3168 - categorical_crossentropy: 1.0971
# Epoch 6/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1275 - categorical_accuracy: 0.3202 - categorical_crossentropy: 1.0968
# Epoch 7/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1269 - categorical_accuracy: 0.3300 - categorical_crossentropy: 1.0962
# Epoch 8/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1269 - categorical_accuracy: 0.3364 - categorical_crossentropy: 1.0963
# Epoch 9/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1272 - categorical_accuracy: 0.3378 - categorical_crossentropy: 1.0965
# Epoch 10/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1266 - categorical_accuracy: 0.3398 - categorical_crossentropy: 1.0960
# Epoch 11/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1270 - categorical_accuracy: 0.3305 - categorical_crossentropy: 1.0964
# Epoch 12/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1269 - categorical_accuracy: 0.3320 - categorical_crossentropy: 1.0964
# Epoch 13/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1271 - categorical_accuracy: 0.3320 - categorical_crossentropy: 1.0966
# Epoch 14/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1274 - categorical_accuracy: 0.3119 - categorical_crossentropy: 1.0970
# Epoch 15/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1273 - categorical_accuracy: 0.3202 - categorical_crossentropy: 1.0969
# Epoch 16/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1270 - categorical_accuracy: 0.3173 - categorical_crossentropy: 1.0967
# Epoch 17/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1266 - categorical_accuracy: 0.3349 - categorical_crossentropy: 1.0963
# Epoch 18/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1265 - categorical_accuracy: 0.3447 - categorical_crossentropy: 1.0962
# Epoch 19/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1270 - categorical_accuracy: 0.3256 - categorical_crossentropy: 1.0967
# Epoch 20/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1266 - categorical_accuracy: 0.3368 - categorical_crossentropy: 1.0964
# Epoch 21/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1267 - categorical_accuracy: 0.3266 - categorical_crossentropy: 1.0964
# Epoch 22/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1270 - categorical_accuracy: 0.3212 - categorical_crossentropy: 1.0968
# Epoch 23/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1265 - categorical_accuracy: 0.3398 - categorical_crossentropy: 1.0963
# Epoch 24/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1266 - categorical_accuracy: 0.3320 - categorical_crossentropy: 1.0965
# Epoch 25/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1264 - categorical_accuracy: 0.3324 - categorical_crossentropy: 1.0964
# Epoch 26/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1264 - categorical_accuracy: 0.3280 - categorical_crossentropy: 1.0964
# Epoch 27/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1265 - categorical_accuracy: 0.3261 - categorical_crossentropy: 1.0965
# Epoch 28/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1262 - categorical_accuracy: 0.3490 - categorical_crossentropy: 1.0963
# Epoch 29/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1265 - categorical_accuracy: 0.3232 - categorical_crossentropy: 1.0965
# Epoch 30/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1262 - categorical_accuracy: 0.3403 - categorical_crossentropy: 1.0963
# Epoch 31/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1265 - categorical_accuracy: 0.3261 - categorical_crossentropy: 1.0966
# Epoch 32/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1261 - categorical_accuracy: 0.3290 - categorical_crossentropy: 1.0963
# Epoch 33/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1263 - categorical_accuracy: 0.3327 - categorical_crossentropy: 1.0965
# Epoch 34/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1263 - categorical_accuracy: 0.3200 - categorical_crossentropy: 1.0966
# Epoch 35/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1259 - categorical_accuracy: 0.3427 - categorical_crossentropy: 1.0962
# Epoch 36/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1259 - categorical_accuracy: 0.3312 - categorical_crossentropy: 1.0962
# Epoch 37/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1261 - categorical_accuracy: 0.3268 - categorical_crossentropy: 1.0964
# Epoch 38/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1259 - categorical_accuracy: 0.3288 - categorical_crossentropy: 1.0963
# Epoch 39/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1261 - categorical_accuracy: 0.3291 - categorical_crossentropy: 1.0965
# Epoch 40/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1259 - categorical_accuracy: 0.3268 - categorical_crossentropy: 1.0964
# Epoch 41/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1262 - categorical_accuracy: 0.3127 - categorical_crossentropy: 1.0967
# Epoch 42/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1254 - categorical_accuracy: 0.3430 - categorical_crossentropy: 1.0959
# Epoch 43/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1256 - categorical_accuracy: 0.3391 - categorical_crossentropy: 1.0961
# Epoch 44/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1258 - categorical_accuracy: 0.3361 - categorical_crossentropy: 1.0964
# Epoch 45/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1255 - categorical_accuracy: 0.3344 - categorical_crossentropy: 1.0961
# Epoch 46/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1258 - categorical_accuracy: 0.3253 - categorical_crossentropy: 1.0965
# Epoch 47/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1257 - categorical_accuracy: 0.3351 - categorical_crossentropy: 1.0964
# Epoch 48/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1258 - categorical_accuracy: 0.3288 - categorical_crossentropy: 1.0966
# Epoch 49/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1257 - categorical_accuracy: 0.3197 - categorical_crossentropy: 1.0965
# Epoch 50/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1255 - categorical_accuracy: 0.3303 - categorical_crossentropy: 1.0963
# Epoch 51/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1256 - categorical_accuracy: 0.3305 - categorical_crossentropy: 1.0964
# Epoch 52/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1255 - categorical_accuracy: 0.3349 - categorical_crossentropy: 1.0963
# Epoch 53/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1255 - categorical_accuracy: 0.3237 - categorical_crossentropy: 1.0964
# Epoch 54/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1253 - categorical_accuracy: 0.3232 - categorical_crossentropy: 1.0962
# Epoch 55/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1252 - categorical_accuracy: 0.3466 - categorical_crossentropy: 1.0962
# Epoch 56/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1254 - categorical_accuracy: 0.3145 - categorical_crossentropy: 1.0964
# Epoch 57/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1249 - categorical_accuracy: 0.3405 - categorical_crossentropy: 1.0960
# Epoch 58/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1250 - categorical_accuracy: 0.3356 - categorical_crossentropy: 1.0961
# Epoch 59/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1252 - categorical_accuracy: 0.3283 - categorical_crossentropy: 1.0962
# Epoch 60/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1251 - categorical_accuracy: 0.3201 - categorical_crossentropy: 1.0963
# Epoch 61/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1251 - categorical_accuracy: 0.3332 - categorical_crossentropy: 1.0962
# Epoch 62/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1250 - categorical_accuracy: 0.3175 - categorical_crossentropy: 1.0962
# Epoch 63/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1250 - categorical_accuracy: 0.3225 - categorical_crossentropy: 1.0962
# Epoch 64/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1251 - categorical_accuracy: 0.3133 - categorical_crossentropy: 1.0964
# Epoch 65/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1249 - categorical_accuracy: 0.3415 - categorical_crossentropy: 1.0962
# Epoch 66/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1248 - categorical_accuracy: 0.3230 - categorical_crossentropy: 1.0962
# Epoch 67/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1248 - categorical_accuracy: 0.3292 - categorical_crossentropy: 1.0961
# Epoch 68/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1249 - categorical_accuracy: 0.3070 - categorical_crossentropy: 1.0963
# Epoch 69/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1247 - categorical_accuracy: 0.3119 - categorical_crossentropy: 1.0962
# Epoch 70/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1246 - categorical_accuracy: 0.3277 - categorical_crossentropy: 1.0961
# Epoch 71/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1245 - categorical_accuracy: 0.3377 - categorical_crossentropy: 1.0960
# Epoch 72/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1248 - categorical_accuracy: 0.3117 - categorical_crossentropy: 1.0963
# Epoch 73/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1247 - categorical_accuracy: 0.3156 - categorical_crossentropy: 1.0963
# Epoch 74/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1244 - categorical_accuracy: 0.3280 - categorical_crossentropy: 1.0960
# Epoch 75/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1246 - categorical_accuracy: 0.3095 - categorical_crossentropy: 1.0962
# Epoch 76/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1246 - categorical_accuracy: 0.3149 - categorical_crossentropy: 1.0962
# Epoch 77/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1247 - categorical_accuracy: 0.2963 - categorical_crossentropy: 1.0964
# Epoch 78/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1244 - categorical_accuracy: 0.3176 - categorical_crossentropy: 1.0961
# Epoch 79/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1244 - categorical_accuracy: 0.3098 - categorical_crossentropy: 1.0962
# Epoch 80/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1245 - categorical_accuracy: 0.3100 - categorical_crossentropy: 1.0963
# Epoch 81/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1244 - categorical_accuracy: 0.3126 - categorical_crossentropy: 1.0962
# Epoch 82/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1244 - categorical_accuracy: 0.3113 - categorical_crossentropy: 1.0962
# Epoch 83/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1243 - categorical_accuracy: 0.3108 - categorical_crossentropy: 1.0962
# Epoch 84/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1242 - categorical_accuracy: 0.3161 - categorical_crossentropy: 1.0961
# Epoch 85/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1242 - categorical_accuracy: 0.3110 - categorical_crossentropy: 1.0962
# Epoch 86/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1242 - categorical_accuracy: 0.3037 - categorical_crossentropy: 1.0962
# Epoch 87/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1242 - categorical_accuracy: 0.3068 - categorical_crossentropy: 1.0962
# Epoch 88/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1242 - categorical_accuracy: 0.3084 - categorical_crossentropy: 1.0963
# Epoch 89/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1241 - categorical_accuracy: 0.3165 - categorical_crossentropy: 1.0962
# Epoch 90/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1240 - categorical_accuracy: 0.3243 - categorical_crossentropy: 1.0961
# Epoch 91/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1240 - categorical_accuracy: 0.3258 - categorical_crossentropy: 1.0961
# Epoch 92/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1240 - categorical_accuracy: 0.3193 - categorical_crossentropy: 1.0962
# Epoch 93/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1240 - categorical_accuracy: 0.3215 - categorical_crossentropy: 1.0962
# Epoch 94/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1239 - categorical_accuracy: 0.3235 - categorical_crossentropy: 1.0961
# Epoch 95/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1239 - categorical_accuracy: 0.3255 - categorical_crossentropy: 1.0961
# Epoch 96/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1239 - categorical_accuracy: 0.3284 - categorical_crossentropy: 1.0962
# Epoch 97/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1239 - categorical_accuracy: 0.3172 - categorical_crossentropy: 1.0962
# Epoch 98/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1238 - categorical_accuracy: 0.3262 - categorical_crossentropy: 1.0961
# Epoch 99/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1237 - categorical_accuracy: 0.3403 - categorical_crossentropy: 1.0961
# Epoch 100/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1238 - categorical_accuracy: 0.3312 - categorical_crossentropy: 1.0962
# Epoch 101/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1236 - categorical_accuracy: 0.3298 - categorical_crossentropy: 1.0961
# Epoch 102/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1238 - categorical_accuracy: 0.3234 - categorical_crossentropy: 1.0963
# Epoch 103/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1236 - categorical_accuracy: 0.3414 - categorical_crossentropy: 1.0961
# Epoch 104/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1235 - categorical_accuracy: 0.3486 - categorical_crossentropy: 1.0960
# Epoch 105/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1235 - categorical_accuracy: 0.3449 - categorical_crossentropy: 1.0961
# Epoch 106/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1236 - categorical_accuracy: 0.3361 - categorical_crossentropy: 1.0962
# Epoch 107/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1234 - categorical_accuracy: 0.3475 - categorical_crossentropy: 1.0960
# Epoch 108/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1234 - categorical_accuracy: 0.3372 - categorical_crossentropy: 1.0961
# Epoch 109/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1234 - categorical_accuracy: 0.3385 - categorical_crossentropy: 1.0961
# Epoch 110/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1233 - categorical_accuracy: 0.3426 - categorical_crossentropy: 1.0961
# Epoch 111/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1234 - categorical_accuracy: 0.3392 - categorical_crossentropy: 1.0962
# Epoch 112/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1232 - categorical_accuracy: 0.3462 - categorical_crossentropy: 1.0960
# Epoch 113/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1232 - categorical_accuracy: 0.3398 - categorical_crossentropy: 1.0960
# Epoch 114/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1233 - categorical_accuracy: 0.3491 - categorical_crossentropy: 1.0961
# Epoch 115/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1232 - categorical_accuracy: 0.3581 - categorical_crossentropy: 1.0961
# Epoch 116/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1232 - categorical_accuracy: 0.3722 - categorical_crossentropy: 1.0961
# Epoch 117/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1232 - categorical_accuracy: 0.3751 - categorical_crossentropy: 1.0962
# Epoch 118/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1231 - categorical_accuracy: 0.3680 - categorical_crossentropy: 1.0961
# Epoch 119/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1232 - categorical_accuracy: 0.3744 - categorical_crossentropy: 1.0962
# Epoch 120/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1231 - categorical_accuracy: 0.3891 - categorical_crossentropy: 1.0961
# Epoch 121/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1230 - categorical_accuracy: 0.3748 - categorical_crossentropy: 1.0961
# Epoch 122/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1231 - categorical_accuracy: 0.3776 - categorical_crossentropy: 1.0962
# Epoch 123/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1229 - categorical_accuracy: 0.3957 - categorical_crossentropy: 1.0960
# Epoch 124/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1230 - categorical_accuracy: 0.3944 - categorical_crossentropy: 1.0962
# Epoch 125/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1230 - categorical_accuracy: 0.3805 - categorical_crossentropy: 1.0962
# Epoch 126/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1228 - categorical_accuracy: 0.3847 - categorical_crossentropy: 1.0961
# Epoch 127/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1227 - categorical_accuracy: 0.3877 - categorical_crossentropy: 1.0960
# Epoch 128/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1229 - categorical_accuracy: 0.3708 - categorical_crossentropy: 1.0962
# Epoch 129/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1227 - categorical_accuracy: 0.4064 - categorical_crossentropy: 1.0960
# Epoch 130/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1228 - categorical_accuracy: 0.3710 - categorical_crossentropy: 1.0961
# Epoch 131/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1227 - categorical_accuracy: 0.3821 - categorical_crossentropy: 1.0961
# Epoch 132/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1226 - categorical_accuracy: 0.3907 - categorical_crossentropy: 1.0960
# Epoch 133/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1226 - categorical_accuracy: 0.3981 - categorical_crossentropy: 1.0960
# Epoch 134/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1226 - categorical_accuracy: 0.3881 - categorical_crossentropy: 1.0961
# Epoch 135/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1226 - categorical_accuracy: 0.3978 - categorical_crossentropy: 1.0961
# Epoch 136/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1225 - categorical_accuracy: 0.3997 - categorical_crossentropy: 1.0961
# Epoch 137/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1225 - categorical_accuracy: 0.3979 - categorical_crossentropy: 1.0960
# Epoch 138/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1224 - categorical_accuracy: 0.3819 - categorical_crossentropy: 1.0960
# Epoch 139/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1224 - categorical_accuracy: 0.3890 - categorical_crossentropy: 1.0961
# Epoch 140/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1224 - categorical_accuracy: 0.3948 - categorical_crossentropy: 1.0961
# Epoch 141/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1224 - categorical_accuracy: 0.3983 - categorical_crossentropy: 1.0961
# Epoch 142/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1223 - categorical_accuracy: 0.3985 - categorical_crossentropy: 1.0960
# Epoch 143/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1224 - categorical_accuracy: 0.3907 - categorical_crossentropy: 1.0962
# Epoch 144/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1223 - categorical_accuracy: 0.4055 - categorical_crossentropy: 1.0961
# Epoch 145/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1223 - categorical_accuracy: 0.4111 - categorical_crossentropy: 1.0961
# Epoch 146/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1222 - categorical_accuracy: 0.4026 - categorical_crossentropy: 1.0961
# Epoch 147/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1221 - categorical_accuracy: 0.4232 - categorical_crossentropy: 1.0960
# Epoch 148/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1221 - categorical_accuracy: 0.4177 - categorical_crossentropy: 1.0960
# Epoch 149/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1220 - categorical_accuracy: 0.4392 - categorical_crossentropy: 1.0960
# Epoch 150/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1221 - categorical_accuracy: 0.4169 - categorical_crossentropy: 1.0961
# Epoch 151/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1220 - categorical_accuracy: 0.4263 - categorical_crossentropy: 1.0960
# Epoch 152/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1221 - categorical_accuracy: 0.4144 - categorical_crossentropy: 1.0961
# Epoch 153/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1220 - categorical_accuracy: 0.4037 - categorical_crossentropy: 1.0961
# Epoch 154/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1220 - categorical_accuracy: 0.4242 - categorical_crossentropy: 1.0961
# Epoch 155/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1219 - categorical_accuracy: 0.4349 - categorical_crossentropy: 1.0960
# Epoch 156/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1219 - categorical_accuracy: 0.4450 - categorical_crossentropy: 1.0960
# Epoch 157/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1218 - categorical_accuracy: 0.4421 - categorical_crossentropy: 1.0959
# Epoch 158/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1218 - categorical_accuracy: 0.4352 - categorical_crossentropy: 1.0960
# Epoch 159/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1218 - categorical_accuracy: 0.4522 - categorical_crossentropy: 1.0961
# Epoch 160/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1218 - categorical_accuracy: 0.4487 - categorical_crossentropy: 1.0961
# Epoch 161/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1218 - categorical_accuracy: 0.4290 - categorical_crossentropy: 1.0961
# Epoch 162/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1218 - categorical_accuracy: 0.4601 - categorical_crossentropy: 1.0961
# Epoch 163/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1217 - categorical_accuracy: 0.4449 - categorical_crossentropy: 1.0961
# Epoch 164/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1217 - categorical_accuracy: 0.4438 - categorical_crossentropy: 1.0961
# Epoch 165/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1217 - categorical_accuracy: 0.4430 - categorical_crossentropy: 1.0961
# Epoch 166/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1217 - categorical_accuracy: 0.4441 - categorical_crossentropy: 1.0961
# Epoch 167/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1215 - categorical_accuracy: 0.4639 - categorical_crossentropy: 1.0960
# Epoch 168/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1216 - categorical_accuracy: 0.4500 - categorical_crossentropy: 1.0961
# Epoch 169/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1214 - categorical_accuracy: 0.4553 - categorical_crossentropy: 1.0960
# Epoch 170/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1214 - categorical_accuracy: 0.4762 - categorical_crossentropy: 1.0959
# Epoch 171/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1214 - categorical_accuracy: 0.4658 - categorical_crossentropy: 1.0960
# Epoch 172/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1215 - categorical_accuracy: 0.4594 - categorical_crossentropy: 1.0961
# Epoch 173/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1214 - categorical_accuracy: 0.4591 - categorical_crossentropy: 1.0961
# Epoch 174/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1213 - categorical_accuracy: 0.4731 - categorical_crossentropy: 1.0960
# Epoch 175/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1213 - categorical_accuracy: 0.4638 - categorical_crossentropy: 1.0960
# Epoch 176/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1214 - categorical_accuracy: 0.4694 - categorical_crossentropy: 1.0961
# Epoch 177/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1214 - categorical_accuracy: 0.4684 - categorical_crossentropy: 1.0961
# Epoch 178/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1212 - categorical_accuracy: 0.4687 - categorical_crossentropy: 1.0960
# Epoch 179/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1212 - categorical_accuracy: 0.4693 - categorical_crossentropy: 1.0960
# Epoch 180/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1211 - categorical_accuracy: 0.4808 - categorical_crossentropy: 1.0959
# Epoch 181/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1212 - categorical_accuracy: 0.4684 - categorical_crossentropy: 1.0960
# Epoch 182/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1211 - categorical_accuracy: 0.4704 - categorical_crossentropy: 1.0960
# Epoch 183/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1211 - categorical_accuracy: 0.4718 - categorical_crossentropy: 1.0960
# Epoch 184/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1210 - categorical_accuracy: 0.4787 - categorical_crossentropy: 1.0960
# Epoch 185/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1209 - categorical_accuracy: 0.4774 - categorical_crossentropy: 1.0959
# Epoch 186/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1210 - categorical_accuracy: 0.4733 - categorical_crossentropy: 1.0960
# Epoch 187/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1210 - categorical_accuracy: 0.4642 - categorical_crossentropy: 1.0960
# Epoch 188/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1208 - categorical_accuracy: 0.4804 - categorical_crossentropy: 1.0959
# Epoch 189/200
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1209 - categorical_accuracy: 0.4684 - categorical_crossentropy: 1.0960
# Epoch 190/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1209 - categorical_accuracy: 0.4750 - categorical_crossentropy: 1.0960
# Epoch 191/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1209 - categorical_accuracy: 0.4613 - categorical_crossentropy: 1.0960
# Epoch 192/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1208 - categorical_accuracy: 0.4808 - categorical_crossentropy: 1.0960
# Epoch 193/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1208 - categorical_accuracy: 0.4859 - categorical_crossentropy: 1.0960
# Epoch 194/200
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1207 - categorical_accuracy: 0.5040 - categorical_crossentropy: 1.0959
# Epoch 195/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1208 - categorical_accuracy: 0.4814 - categorical_crossentropy: 1.0961
# Epoch 196/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1207 - categorical_accuracy: 0.4823 - categorical_crossentropy: 1.0960
# Epoch 197/200
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1208 - categorical_accuracy: 0.4686 - categorical_crossentropy: 1.0961
# Epoch 198/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1207 - categorical_accuracy: 0.4872 - categorical_crossentropy: 1.0960
# Epoch 199/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1206 - categorical_accuracy: 0.4928 - categorical_crossentropy: 1.0960
# Epoch 200/200
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1205 - categorical_accuracy: 0.4867 - categorical_crossentropy: 1.0959
# LearningShapelets(max_iter=200, n_shapelets_per_size={12: 5}, verbose=1,
#                   weight_regularizer=0.01)

# %%
y_pred = shp_clf.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.51
# F1-score [0.61621622 0.58181818 0.32820513]
#               precision    recall  f1-score   support
#
#            0       0.67      0.57      0.62       100
#            1       0.53      0.64      0.58       100
#            2       0.34      0.32      0.33       100
#
#     accuracy                           0.51       300
#    macro avg       0.51      0.51      0.51       300
# weighted avg       0.51      0.51      0.51       300

# %% [markdown]
# # Shaplet-distances-based Classifier

# %%
X_train2 = shp_clf.transform(X_train)
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
X_train2.shape
# Out:
# (700, 5)

# %%
X_train2
# Out:
# array([[0.0331587 , 0.0106956 , 0.01050229, 0.00733074, 0.00640567],
#        [0.03564262, 0.01065683, 0.00392374, 0.00743167, 0.00544429],
#        [0.03814507, 0.0153145 , 0.00808844, 0.00853705, 0.01108607],
#        ...,
#        [0.0242664 , 0.05026506, 0.01195386, 0.01272066, 0.00510796],
#        [0.03480439, 0.01279199, 0.00489511, 0.01059381, 0.01048025],
#        [0.01619522, 0.00879562, 0.00941893, 0.00824992, 0.01321507]],
#       dtype=float32)

# %%
X_test2 = shp_clf.transform(X_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train2, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.71
# F1-score [0.99497487 0.55837563 0.57843137]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       100
#            1       0.57      0.55      0.56       100
#            2       0.57      0.59      0.58       100
#
#     accuracy                           0.71       300
#    macro avg       0.71      0.71      0.71       300
# weighted avg       0.71      0.71      0.71       300

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train2, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.7166666666666667
# F1-score [0.98492462 0.60829493 0.55434783]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       100
#            1       0.56      0.66      0.61       100
#            2       0.61      0.51      0.55       100
#
#     accuracy                           0.72       300
#    macro avg       0.72      0.72      0.72       300
# weighted avg       0.72      0.72      0.72       300

# %% [markdown]
# # Feature-based Classifier

# %%
import scipy.stats as stats

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
X_train3 = np.array([list(calculate_features(x).values()) for x in X_train])

# %%
X_train3.shape
# Out:
# (700, 13)

# %%
X_train3
# Out:
# array([[ 0.39859446,  0.23519191,  0.05531524, ...,  1.69476262,
#          0.36034213, -0.8842845 ],
#        [ 0.45011623,  0.21610026,  0.04669932, ...,  2.08290465,
#          0.32862626, -0.61767966],
#        [ 0.42219464,  0.22458385,  0.05043791, ...,  1.87989759,
#          0.27583263, -0.91630096],
#        ...,
#        [ 0.52655729,  0.28183322,  0.07942997, ...,  1.86832936,
#         -0.46340955, -1.14728378],
#        [ 0.45154156,  0.22410403,  0.05022261, ...,  2.0148748 ,
#          0.19409557, -0.63827757],
#        [ 0.44552984,  0.20088531,  0.04035491, ...,  2.21783187,
#          0.41476313, -0.20365056]])

# %%
X_test3 = np.array([list(calculate_features(x).values()) for x in X_test])

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train3, y_train)

y_pred = clf.predict(X_test3)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6733333333333333
# F1-score [1.         0.45555556 0.55454545]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       0.51      0.41      0.46       100
#            2       0.51      0.61      0.55       100
#
#     accuracy                           0.67       300
#    macro avg       0.67      0.67      0.67       300
# weighted avg       0.67      0.67      0.67       300

# %% [markdown]
# # Time Series Classifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9733333333333334
# F1-score [0.95918367 0.99       0.97058824]
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       100
#            1       0.99      0.99      0.99       100
#            2       0.95      0.99      0.97       100
#
#     accuracy                           0.97       300
#    macro avg       0.97      0.97      0.97       300
# weighted avg       0.97      0.97      0.97       300

# %%
from pyts.classification import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(metric='dtw_sakoechiba')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %% [markdown]
# # CNN Classifier

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling1D
from keras.layers import Conv1D, Activation, Conv1D, BatchNormalization

# %%
def build_simple_cnn(n_timesteps, n_outputs):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, 1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_cnn = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train_cnn, y_train, test_size=0.2, stratify=y_train)

n_timesteps, n_outputs, n_features = X_train_cnn.shape[1], len(np.unique(y_train_cnn)), 1 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
# Out:
# TIMESTEPS:  128
# N. LABELS:  3

# %%
cnn = build_simple_cnn(n_timesteps, n_outputs)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 121, 16)           144
# _________________________________________________________________
# batch_normalization (BatchNo (None, 121, 16)           64
# _________________________________________________________________
# activation (Activation)      (None, 121, 16)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 121, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 117, 32)           2592
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 117, 32)           128
# _________________________________________________________________
# activation_1 (Activation)    (None, 117, 32)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 117, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 115, 64)           6208
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 115, 64)           256
# _________________________________________________________________
# activation_2 (Activation)    (None, 115, 64)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 115, 64)           0
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 195
# =================================================================
# Total params: 9,587
# Trainable params: 9,363
# Non-trainable params: 224
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train_cnn.shape[0]/10, batch_size))

# %%
history_cnn = cnn.fit(X_train_cnn, y_train_cnn, epochs=5, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Epoch 1/5
# 35/35 [==============================] - 3s 22ms/step - loss: 0.9259 - accuracy: 0.5466 - val_loss: 1.0814 - val_accuracy: 0.6357
# Epoch 2/5
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5708 - accuracy: 0.8733 - val_loss: 1.0840 - val_accuracy: 0.3357
# Epoch 3/5
# 35/35 [==============================] - 0s 7ms/step - loss: 0.4310 - accuracy: 0.9339 - val_loss: 1.0796 - val_accuracy: 0.3357
# Epoch 4/5
# 35/35 [==============================] - 0s 6ms/step - loss: 0.2862 - accuracy: 0.9852 - val_loss: 1.0657 - val_accuracy: 0.3357
# Epoch 5/5
# 35/35 [==============================] - 0s 6ms/step - loss: 0.2402 - accuracy: 0.9842 - val_loss: 1.0493 - val_accuracy: 0.3357

# %%
y_pred = np.argmax(cnn.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.34
# F1-score [0.         0.50890585 0.03738318]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       100
#            1       0.34      1.00      0.51       100
#            2       0.29      0.02      0.04       100
#
#     accuracy                           0.34       300
#    macro avg       0.21      0.34      0.18       300
# weighted avg       0.21      0.34      0.18       300
# /Users/riccardo/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cnn.evaluate(X_test_cnn, y_test)
# Out:
# 300/300 [==============================] - 0s 90us/step
# [1.0486841090520223, 0.3400000035762787]

# %% [markdown]
# # LSTM Classifier

# %%
from keras.layers import LSTM

# %%
def build_lstm(n_timesteps, n_outputs):
    model = Sequential()
    model.add(LSTM(256, input_shape=(n_timesteps, 1)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm = build_lstm(n_timesteps, n_outputs)

# %%
lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               264192
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 280,835
# Trainable params: 280,835
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm = cnn.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=mini_batch_size, callbacks=callbacks,
                       validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4599ad6f27e1> in <module>
# ----> 1 history_lstm = cnn.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=mini_batch_size, callbacks=callbacks,
#       2                        validation_data=(X_val_cnn, y_val_cnn)).history
#
# NameError: name 'mini_batch_size' is not defined

# %%
y_pred = np.argmax(lstm.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.3333333333333333
# F1-score [0.  0.5 0. ]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       100
#            1       0.33      1.00      0.50       100
#            2       0.00      0.00      0.00       100
#
#     accuracy                           0.33       300
#    macro avg       0.11      0.33      0.17       300
# weighted avg       0.11      0.33      0.17       300

# %%
lstm.evaluate(X_test_cnn, y_test)
# Out:
# 300/300 [==============================] - 0s 1ms/step
# [1.0984290631612141, 0.3333333432674408]

# %% [markdown]
# # Multivariate Time Series Classifiers

# %%
from pyts.datasets import load_basic_motions

from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
X_train, X_test, y_train, y_test = load_basic_motions(return_X_y=True)
X_train.shape
# Out:
# (40, 6, 100)

# %%
scaler = TimeSeriesScalerMinMax()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train.shape
# Out:
# (40,)

# %%
y_train
# Out:
# array([b'Standing', b'Standing', b'Standing', b'Standing', b'Standing',
#        b'Standing', b'Standing', b'Standing', b'Standing', b'Standing',
#        b'Running', b'Running', b'Running', b'Running', b'Running',
#        b'Running', b'Running', b'Running', b'Running', b'Running',
#        b'Walking', b'Walking', b'Walking', b'Walking', b'Walking',
#        b'Walking', b'Walking', b'Walking', b'Walking', b'Walking',
#        b'Badminton', b'Badminton', b'Badminton', b'Badminton',
#        b'Badminton', b'Badminton', b'Badminton', b'Badminton',
#        b'Badminton', b'Badminton'], dtype='|S12')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
X_train = X_train.reshape(40, 100, 6)
X_test = X_test.reshape(40, 100, 6)

# %%
n_timesteps, n_outputs, n_features = X_train.shape[1], len(np.unique(y_train)), X_train.shape[2] 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
print("N. FEATURES: ", n_features)
# Out:
# TIMESTEPS:  100
# N. LABELS:  4
# N. FEATURES:  6

# %%
X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers import TimeDistributed
from keras.layers.recurrent import LSTM
from keras.layers import Dense, Conv1D, Conv2D, MaxPool2D, Flatten, Dropout, LeakyReLU, GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
def build_lstm2(n_timesteps, n_outputs, n_features):
    model = Sequential()
    model.add(LSTM(4, input_shape=(n_timesteps, n_features), return_sequences=True, 
                        kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.3))
    
    #1
    for _ in range(2):
        model.add(LSTM(4, kernel_initializer='TruncatedNormal', return_sequences=True))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.04))   

    #2
    model.add(LSTM(32, kernel_initializer='TruncatedNormal', return_sequences=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
    
    #3
    for _ in range(2):
        model.add(Dense(256, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))
    #4
    for _ in range(1):
        model.add(Dense(64, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.7))

    #5
    model.add(Dense(32, kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.4))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm2 = build_lstm2(n_timesteps, n_outputs, n_features)

# %%
lstm2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 100, 4)            176
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 100, 4)            16
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 100, 4)            0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 100, 4)            0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 100, 4)            144
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 100, 4)            16
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 100, 4)            0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 100, 4)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 4)            144
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 100, 4)            16
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 100, 4)            0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 100, 4)            0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 32)                4736
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               8448
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 256)               1024
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 256)               1024
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                16448
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 32)                128
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 132
# =================================================================
# Total params: 100,708
# Trainable params: 99,404
# Non-trainable params: 1,304
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_lstm2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_lstm2 = lstm2.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                          validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 4s 120ms/step - loss: 1.6396 - accuracy: 0.2500 - val_loss: 1.3863 - val_accuracy: 0.2500
# Epoch 2/50
# 32/32 [==============================] - 1s 30ms/step - loss: 1.3807 - accuracy: 0.4062 - val_loss: 1.3863 - val_accuracy: 0.2500
# Epoch 3/50
# 32/32 [==============================] - 1s 32ms/step - loss: 1.4749 - accuracy: 0.2188 - val_loss: 1.3863 - val_accuracy: 0.2500
# Epoch 4/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4223 - accuracy: 0.2188 - val_loss: 1.3863 - val_accuracy: 0.2500
# Epoch 5/50
# 32/32 [==============================] - 1s 33ms/step - loss: 1.3451 - accuracy: 0.4062 - val_loss: 1.3863 - val_accuracy: 0.2500
# Epoch 6/50
# 32/32 [==============================] - 1s 32ms/step - loss: 1.4631 - accuracy: 0.2500 - val_loss: 1.3864 - val_accuracy: 0.2500
# Epoch 7/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4985 - accuracy: 0.2188 - val_loss: 1.3864 - val_accuracy: 0.2500
# Epoch 8/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3982 - accuracy: 0.3438 - val_loss: 1.3865 - val_accuracy: 0.2500
# Epoch 9/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3987 - accuracy: 0.3125 - val_loss: 1.3865 - val_accuracy: 0.2500
# Epoch 10/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.5110 - accuracy: 0.2812 - val_loss: 1.3864 - val_accuracy: 0.2500
# Epoch 11/50
# 32/32 [==============================] - 1s 33ms/step - loss: 1.2976 - accuracy: 0.4375 - val_loss: 1.3865 - val_accuracy: 0.2500
# Epoch 12/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.5131 - accuracy: 0.3438 - val_loss: 1.3867 - val_accuracy: 0.2500
# Epoch 13/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4397 - accuracy: 0.4688 - val_loss: 1.3869 - val_accuracy: 0.2500
# Epoch 14/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.3529 - accuracy: 0.3125 - val_loss: 1.3870 - val_accuracy: 0.2500
# Epoch 15/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4446 - accuracy: 0.3125 - val_loss: 1.3872 - val_accuracy: 0.2500
# Epoch 16/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.3606 - accuracy: 0.3125 - val_loss: 1.3872 - val_accuracy: 0.2500
# Epoch 17/50
# 32/32 [==============================] - 1s 33ms/step - loss: 1.2436 - accuracy: 0.3125 - val_loss: 1.3875 - val_accuracy: 0.2500
# Epoch 18/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4079 - accuracy: 0.2812 - val_loss: 1.3879 - val_accuracy: 0.2500
# Epoch 19/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.2856 - accuracy: 0.3125 - val_loss: 1.3885 - val_accuracy: 0.2500
# Epoch 20/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.4732 - accuracy: 0.2812 - val_loss: 1.3890 - val_accuracy: 0.2500
# Epoch 21/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.3294 - accuracy: 0.5312 - val_loss: 1.3897 - val_accuracy: 0.2500
# Epoch 22/50
# 32/32 [==============================] - 1s 33ms/step - loss: 1.2545 - accuracy: 0.4062 - val_loss: 1.3906 - val_accuracy: 0.2500
# Epoch 23/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.2595 - accuracy: 0.2500 - val_loss: 1.3913 - val_accuracy: 0.2500
# Epoch 24/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.2807 - accuracy: 0.3125 - val_loss: 1.3923 - val_accuracy: 0.2500
# Epoch 25/50
# 32/32 [==============================] - 1s 38ms/step - loss: 1.2815 - accuracy: 0.2500 - val_loss: 1.3929 - val_accuracy: 0.2500
# Epoch 26/50
# 32/32 [==============================] - 1s 38ms/step - loss: 1.3232 - accuracy: 0.3125 - val_loss: 1.3940 - val_accuracy: 0.2500
# Epoch 27/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.5695 - accuracy: 0.1875 - val_loss: 1.3953 - val_accuracy: 0.2500
# Epoch 28/50
# 32/32 [==============================] - 1s 37ms/step - loss: 1.2730 - accuracy: 0.3438 - val_loss: 1.3958 - val_accuracy: 0.2500
# Epoch 29/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.4051 - accuracy: 0.2812 - val_loss: 1.3969 - val_accuracy: 0.2500
# Epoch 30/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.3944 - accuracy: 0.3750 - val_loss: 1.3968 - val_accuracy: 0.2500
# Epoch 31/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.2970 - accuracy: 0.3125 - val_loss: 1.3969 - val_accuracy: 0.2500
# Epoch 32/50
# 32/32 [==============================] - 1s 39ms/step - loss: 1.3477 - accuracy: 0.4375 - val_loss: 1.3967 - val_accuracy: 0.2500
# Epoch 33/50
# 32/32 [==============================] - 1s 38ms/step - loss: 1.4630 - accuracy: 0.3125 - val_loss: 1.3967 - val_accuracy: 0.2500
# Epoch 34/50
# 32/32 [==============================] - 1s 37ms/step - loss: 1.1793 - accuracy: 0.3750 - val_loss: 1.3965 - val_accuracy: 0.2500
# Epoch 35/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3082 - accuracy: 0.3750 - val_loss: 1.3964 - val_accuracy: 0.2500
# Epoch 36/50
# 32/32 [==============================] - 1s 40ms/step - loss: 1.4891 - accuracy: 0.1875 - val_loss: 1.3966 - val_accuracy: 0.2500
# Epoch 37/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.2156 - accuracy: 0.3750 - val_loss: 1.3966 - val_accuracy: 0.2500
# Epoch 38/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3283 - accuracy: 0.4375 - val_loss: 1.3959 - val_accuracy: 0.2500
# Epoch 39/50
# 32/32 [==============================] - 1s 38ms/step - loss: 1.1527 - accuracy: 0.4688 - val_loss: 1.3961 - val_accuracy: 0.2500
# Epoch 40/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3443 - accuracy: 0.5000 - val_loss: 1.3959 - val_accuracy: 0.2500
# Epoch 41/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.2797 - accuracy: 0.3750 - val_loss: 1.3972 - val_accuracy: 0.2500
# Epoch 42/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.2660 - accuracy: 0.4062 - val_loss: 1.3964 - val_accuracy: 0.2500
# Epoch 43/50
# 32/32 [==============================] - 1s 34ms/step - loss: 1.4138 - accuracy: 0.3125 - val_loss: 1.3966 - val_accuracy: 0.2500
# Epoch 44/50
# 32/32 [==============================] - 1s 35ms/step - loss: 1.4468 - accuracy: 0.3125 - val_loss: 1.3972 - val_accuracy: 0.2500
# Epoch 45/50
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3009 - accuracy: 0.3438 - val_loss: 1.3966 - val_accuracy: 0.2500
# Epoch 46/50
# 32/32 [==============================] - 1s 37ms/step - loss: 1.2730 - accuracy: 0.5000 - val_loss: 1.3968 - val_accuracy: 0.2500
# Epoch 47/50
# 32/32 [==============================] - 1s 37ms/step - loss: 1.1731 - accuracy: 0.4062 - val_loss: 1.3969 - val_accuracy: 0.2500
# Epoch 48/50
# 32/32 [==============================] - 1s 38ms/step - loss: 1.2492 - accuracy: 0.4375 - val_loss: 1.3967 - val_accuracy: 0.2500
# Epoch 49/50
# 32/32 [==============================] - 1s 40ms/step - loss: 1.1663 - accuracy: 0.4688 - val_loss: 1.3977 - val_accuracy: 0.2500
# Epoch 50/50
# 32/32 [==============================] - 1s 40ms/step - loss: 1.3673 - accuracy: 0.4062 - val_loss: 1.3955 - val_accuracy: 0.2500

# %%
y_pred = np.argmax(lstm2.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.25
# F1-score [0.  0.  0.  0.4]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00        10
#            3       0.25      1.00      0.40        10
#
#     accuracy                           0.25        40
#    macro avg       0.06      0.25      0.10        40
# weighted avg       0.06      0.25      0.10        40
# /Users/riccardo/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train_cnn.shape
# Out:
# (32, 100, 6)

# %%
X_train_cnn2 = X_train_cnn.reshape(X_train_cnn.shape[0], X_train_cnn.shape[1], X_train_cnn.shape[2], 1)
X_val_cnn2 = X_val_cnn.reshape(X_val_cnn.shape[0], X_val_cnn.shape[1], X_val_cnn.shape[2], 1)
X_test_cnn2 = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

X_train_cnn2.shape
# Out:
# (32, 100, 6, 1)

# %%
def build_cnn2(n_timesteps, n_features, n_outputs):
    input_shape = (n_timesteps, n_features, 1)

    model = Sequential()
    
    ks1_first = 3
    ks1_second = 3
    
    ks2_first = 4
    ks2_second = 4
    
    model.add(Conv2D(filters=(3), 
                     kernel_size=(ks1_first, ks1_second),
                     input_shape=input_shape, 
                     padding='same',
                     kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.02))
    
    for _ in range(2):
        model.add(Conv2D(filters=(4), 
                     kernel_size= (ks2_first, ks2_second), 
                         padding='same',
                     kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))  
    
    model.add(Flatten())
    
    for _ in range(4):
        model.add(Dense(64 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.4))
    
    for _ in range(3):
        model.add(Dense(128 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.3))
  
    model.add(Dense(1024 , kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn2 = build_cnn2(n_timesteps, n_features, n_outputs)

# %%
cnn2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 100, 6, 3)         30
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 100, 6, 3)         12
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 100, 6, 3)         0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 100, 6, 3)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 6, 4)         196
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 100, 6, 4)         16
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 100, 6, 4)         0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 100, 6, 4)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 100, 6, 4)         260
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 100, 6, 4)         16
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 100, 6, 4)         0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 100, 6, 4)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2400)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                153664
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 64)                256
# _________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               8320
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 128)               512
# _________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1024)              132096
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 1024)              4096
# _________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 4)                 4100
# =================================================================
# Total params: 350,870
# Trainable params: 347,520
# Non-trainable params: 3,350
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn2 = cnn2.fit(X_train_cnn2, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn2, y_val_cnn)).history
# Out:
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 2s 74ms/step - loss: 1.8272 - accuracy: 0.1562 - val_loss: 1.3863 - val_accuracy: 0.2500
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6504 - accuracy: 0.3438 - val_loss: 1.3864 - val_accuracy: 0.2500
# Epoch 3/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.6615 - accuracy: 0.2812 - val_loss: 1.3865 - val_accuracy: 0.2500
# Epoch 4/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7045 - accuracy: 0.2812 - val_loss: 1.3867 - val_accuracy: 0.2500
# Epoch 5/50
# 32/32 [==============================] - 0s 3ms/step - loss: 2.1631 - accuracy: 0.1875 - val_loss: 1.3868 - val_accuracy: 0.2500
# Epoch 6/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6088 - accuracy: 0.2188 - val_loss: 1.3869 - val_accuracy: 0.2500
# Epoch 7/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.7161 - accuracy: 0.2812 - val_loss: 1.3872 - val_accuracy: 0.2500
# Epoch 8/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6336 - accuracy: 0.3438 - val_loss: 1.3875 - val_accuracy: 0.2500
# Epoch 9/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4444 - accuracy: 0.2812 - val_loss: 1.3882 - val_accuracy: 0.2500
# Epoch 10/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.7097 - accuracy: 0.3750 - val_loss: 1.3884 - val_accuracy: 0.2500
# Epoch 11/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4574 - accuracy: 0.3750 - val_loss: 1.3879 - val_accuracy: 0.2500
# Epoch 12/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8774 - accuracy: 0.2188 - val_loss: 1.3884 - val_accuracy: 0.2500
# Epoch 13/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5676 - accuracy: 0.2812 - val_loss: 1.3890 - val_accuracy: 0.2500
# Epoch 14/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1729 - accuracy: 0.3438 - val_loss: 1.3897 - val_accuracy: 0.2500
# Epoch 15/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.4196 - accuracy: 0.3750 - val_loss: 1.3903 - val_accuracy: 0.2500
# Epoch 16/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3558 - accuracy: 0.3125 - val_loss: 1.3913 - val_accuracy: 0.2500
# Epoch 17/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5615 - accuracy: 0.3438 - val_loss: 1.3929 - val_accuracy: 0.2500
# Epoch 18/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4723 - accuracy: 0.2812 - val_loss: 1.3945 - val_accuracy: 0.2500
# Epoch 19/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4228 - accuracy: 0.2500 - val_loss: 1.3959 - val_accuracy: 0.2500
# Epoch 20/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.6014 - accuracy: 0.1562 - val_loss: 1.3948 - val_accuracy: 0.2500
# Epoch 21/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3968 - accuracy: 0.3125 - val_loss: 1.3953 - val_accuracy: 0.2500
# Epoch 22/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4730 - accuracy: 0.3438 - val_loss: 1.3968 - val_accuracy: 0.2500
# Epoch 23/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4776 - accuracy: 0.2812 - val_loss: 1.3985 - val_accuracy: 0.2500
# Epoch 24/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3880 - accuracy: 0.3125 - val_loss: 1.3994 - val_accuracy: 0.2500
# Epoch 25/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3957 - accuracy: 0.3438 - val_loss: 1.4017 - val_accuracy: 0.2500
# Epoch 26/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3530 - accuracy: 0.3438 - val_loss: 1.4039 - val_accuracy: 0.2500
# Epoch 27/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5212 - accuracy: 0.2500 - val_loss: 1.4042 - val_accuracy: 0.2500
# Epoch 28/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4691 - accuracy: 0.3750 - val_loss: 1.4024 - val_accuracy: 0.2500
# Epoch 29/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5327 - accuracy: 0.1562 - val_loss: 1.4012 - val_accuracy: 0.2500
# Epoch 30/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4108 - accuracy: 0.2812 - val_loss: 1.3965 - val_accuracy: 0.2500
# Epoch 31/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3100 - accuracy: 0.2812 - val_loss: 1.3927 - val_accuracy: 0.2500
# Epoch 32/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4827 - accuracy: 0.2812 - val_loss: 1.3873 - val_accuracy: 0.2500
# Epoch 33/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4206 - accuracy: 0.5312 - val_loss: 1.3842 - val_accuracy: 0.2500
# Epoch 34/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4358 - accuracy: 0.1875 - val_loss: 1.3803 - val_accuracy: 0.2500
# Epoch 35/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4078 - accuracy: 0.4062 - val_loss: 1.3749 - val_accuracy: 0.2500
# Epoch 36/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3828 - accuracy: 0.4375 - val_loss: 1.3715 - val_accuracy: 0.2500
# Epoch 37/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3863 - accuracy: 0.4688 - val_loss: 1.3679 - val_accuracy: 0.2500
# Epoch 38/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1948 - accuracy: 0.3750 - val_loss: 1.3635 - val_accuracy: 0.2500
# Epoch 39/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.4415 - accuracy: 0.3125 - val_loss: 1.3606 - val_accuracy: 0.2500
# Epoch 40/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3037 - accuracy: 0.3125 - val_loss: 1.3612 - val_accuracy: 0.2500
# Epoch 41/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3122 - accuracy: 0.4062 - val_loss: 1.3595 - val_accuracy: 0.2500
# Epoch 42/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1783 - accuracy: 0.5625 - val_loss: 1.3552 - val_accuracy: 0.2500
# Epoch 43/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.5319 - accuracy: 0.5000 - val_loss: 1.3500 - val_accuracy: 0.3750
# Epoch 44/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.2696 - accuracy: 0.5312 - val_loss: 1.3442 - val_accuracy: 0.3750
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1187 - accuracy: 0.4688 - val_loss: 1.3347 - val_accuracy: 0.3750
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0927 - accuracy: 0.5625 - val_loss: 1.3282 - val_accuracy: 0.3750
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.3168 - accuracy: 0.3750 - val_loss: 1.3186 - val_accuracy: 0.3750
# Epoch 48/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.2313 - accuracy: 0.5625 - val_loss: 1.3058 - val_accuracy: 0.3750
# Epoch 49/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.2542 - accuracy: 0.6250 - val_loss: 1.2985 - val_accuracy: 0.3750
# Epoch 50/50
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1461 - accuracy: 0.4375 - val_loss: 1.2980 - val_accuracy: 0.3750

# %%
y_pred = np.argmax(cnn2.predict(X_test_cnn2), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.4
# F1-score [0.45454545 0.         0.75       0.        ]
#               precision    recall  f1-score   support
#
#            0       0.29      1.00      0.45        10
#            1       0.00      0.00      0.00        10
#            2       1.00      0.60      0.75        10
#            3       0.00      0.00      0.00        10
#
#     accuracy                           0.40        40
#    macro avg       0.32      0.40      0.30        40
# weighted avg       0.32      0.40      0.30        40

# %%
def build_cnn3(n_timesteps, n_outputs, n_features):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, n_features)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn3 = build_cnn3(n_timesteps, n_outputs, n_features)

# %%
cnn3.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 93, 16)            784
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 93, 16)            64
# _________________________________________________________________
# activation_7 (Activation)    (None, 93, 16)            0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 93, 16)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 89, 32)            2592
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 89, 32)            128
# _________________________________________________________________
# activation_8 (Activation)    (None, 89, 32)            0
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 89, 32)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 87, 64)            6208
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 87, 64)            256
# _________________________________________________________________
# activation_9 (Activation)    (None, 87, 64)            0
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 87, 64)            0
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_33 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 10,292
# Trainable params: 10,068
# Non-trainable params: 224
# _________________________________________________________________
# None

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn3 = cnn3.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 32 samples, validate on 8 samples
# Epoch 1/50
# 32/32 [==============================] - 1s 39ms/step - loss: 1.4343 - accuracy: 0.2500 - val_loss: 1.3885 - val_accuracy: 0.2500
# Epoch 2/50
# 32/32 [==============================] - 0s 2ms/step - loss: 1.3860 - accuracy: 0.2812 - val_loss: 1.3847 - val_accuracy: 0.2500
# Epoch 3/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.3422 - accuracy: 0.2812 - val_loss: 1.3822 - val_accuracy: 0.2500
# Epoch 4/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.3020 - accuracy: 0.4062 - val_loss: 1.3811 - val_accuracy: 0.2500
# Epoch 5/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.2780 - accuracy: 0.4375 - val_loss: 1.3802 - val_accuracy: 0.5000
# Epoch 6/50
# 32/32 [==============================] - 0s 2ms/step - loss: 1.2428 - accuracy: 0.4375 - val_loss: 1.3804 - val_accuracy: 0.5000
# Epoch 7/50
# 32/32 [==============================] - 0s 2ms/step - loss: 1.2198 - accuracy: 0.4688 - val_loss: 1.3798 - val_accuracy: 0.2500
# Epoch 8/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1464 - accuracy: 0.5938 - val_loss: 1.3791 - val_accuracy: 0.3750
# Epoch 9/50
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0697 - accuracy: 0.7188 - val_loss: 1.3778 - val_accuracy: 0.5000
# Epoch 10/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0818 - accuracy: 0.6562 - val_loss: 1.3767 - val_accuracy: 0.5000
# Epoch 11/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0874 - accuracy: 0.6562 - val_loss: 1.3734 - val_accuracy: 0.5000
# Epoch 12/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9054 - accuracy: 0.8438 - val_loss: 1.3693 - val_accuracy: 0.5000
# Epoch 13/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9326 - accuracy: 0.7500 - val_loss: 1.3625 - val_accuracy: 0.6250
# Epoch 14/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8309 - accuracy: 0.8750 - val_loss: 1.3550 - val_accuracy: 0.6250
# Epoch 15/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7892 - accuracy: 0.8750 - val_loss: 1.3440 - val_accuracy: 0.6250
# Epoch 16/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8413 - accuracy: 0.7812 - val_loss: 1.3328 - val_accuracy: 0.6250
# Epoch 17/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7660 - accuracy: 0.8125 - val_loss: 1.3188 - val_accuracy: 0.6250
# Epoch 18/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7846 - accuracy: 0.8125 - val_loss: 1.2973 - val_accuracy: 0.6250
# Epoch 19/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7034 - accuracy: 0.8750 - val_loss: 1.2783 - val_accuracy: 0.6250
# Epoch 20/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6947 - accuracy: 0.8750 - val_loss: 1.2593 - val_accuracy: 0.7500
# Epoch 21/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5635 - accuracy: 0.9688 - val_loss: 1.2273 - val_accuracy: 0.6250
# Epoch 22/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.9062 - val_loss: 1.1912 - val_accuracy: 0.6250
# Epoch 23/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5051 - accuracy: 0.9688 - val_loss: 1.1596 - val_accuracy: 0.6250
# Epoch 24/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5593 - accuracy: 0.8438 - val_loss: 1.1349 - val_accuracy: 0.6250
# Epoch 25/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5922 - accuracy: 0.8438 - val_loss: 1.1213 - val_accuracy: 0.6250
# Epoch 26/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4822 - accuracy: 0.9375 - val_loss: 1.0962 - val_accuracy: 0.7500
# Epoch 27/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.9375 - val_loss: 1.0408 - val_accuracy: 0.7500
# Epoch 28/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3939 - accuracy: 0.8750 - val_loss: 0.9920 - val_accuracy: 0.7500
# Epoch 29/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.9375 - val_loss: 0.9457 - val_accuracy: 0.7500
# Epoch 30/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.9062 - val_loss: 0.9050 - val_accuracy: 0.7500
# Epoch 31/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3878 - accuracy: 0.9375 - val_loss: 0.8623 - val_accuracy: 0.7500
# Epoch 32/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.9062 - val_loss: 0.8375 - val_accuracy: 0.6250
# Epoch 33/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3592 - accuracy: 0.9062 - val_loss: 0.8319 - val_accuracy: 0.5000
# Epoch 34/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4836 - accuracy: 0.9062 - val_loss: 0.8456 - val_accuracy: 0.5000
# Epoch 35/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2455 - accuracy: 0.9688 - val_loss: 0.8310 - val_accuracy: 0.5000
# Epoch 36/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.9062 - val_loss: 0.8008 - val_accuracy: 0.5000
# Epoch 37/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2431 - accuracy: 1.0000 - val_loss: 0.7833 - val_accuracy: 0.5000
# Epoch 38/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4630 - accuracy: 0.8750 - val_loss: 0.7612 - val_accuracy: 0.5000
# Epoch 39/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2237 - accuracy: 0.9688 - val_loss: 0.7423 - val_accuracy: 0.6250
# Epoch 40/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3096 - accuracy: 1.0000 - val_loss: 0.7297 - val_accuracy: 0.6250
# Epoch 41/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3127 - accuracy: 0.8750 - val_loss: 0.7251 - val_accuracy: 0.7500
# Epoch 42/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2614 - accuracy: 0.9688 - val_loss: 0.7432 - val_accuracy: 0.7500
# Epoch 43/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3565 - accuracy: 0.9062 - val_loss: 0.7250 - val_accuracy: 0.7500
# Epoch 44/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2003 - accuracy: 1.0000 - val_loss: 0.6891 - val_accuracy: 0.7500
# Epoch 45/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2251 - accuracy: 1.0000 - val_loss: 0.6591 - val_accuracy: 0.7500
# Epoch 46/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.9062 - val_loss: 0.6429 - val_accuracy: 0.8750
# Epoch 47/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 1.0000 - val_loss: 0.6281 - val_accuracy: 0.8750
# Epoch 48/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2391 - accuracy: 0.9375 - val_loss: 0.6253 - val_accuracy: 0.6250
# Epoch 49/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4578 - accuracy: 0.9062 - val_loss: 0.6614 - val_accuracy: 0.6250
# Epoch 50/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.9375 - val_loss: 0.7002 - val_accuracy: 0.6250

# %%
y_pred = np.argmax(cnn3.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.75
# F1-score [0.57142857 0.76190476 0.72727273 0.86956522]
#               precision    recall  f1-score   support
#
#            0       1.00      0.40      0.57        10
#            1       0.73      0.80      0.76        10
#            2       0.67      0.80      0.73        10
#            3       0.77      1.00      0.87        10
#
#     accuracy                           0.75        40
#    macro avg       0.79      0.75      0.73        40
# weighted avg       0.79      0.75      0.73        40

# %% [markdown]
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.multivariate.classification.MultivariateClassifier.html#pyts.multivariate.classification.MultivariateClassifier
