# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

import matplotlib.pyplot as plt

from collections import defaultdict

# %% [markdown]
# ## Import data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# define directory path
directory = "drive/MyDrive/Progetto Data Mining 2/CODICE PROGETTO/Time Series/DATASET/"
df = pd.read_csv("drive/MyDrive/Progetto Data Mining 2/DATASET/RavdessAudioOnlyFeatures_TRAIN.csv")

# import ts data
df_train = pd.read_csv(directory + "Approximated/ts_data_TRAIN_PAA.csv", index_col="Unnamed: 0")
df_test = pd.read_csv(directory + "Approximated/ts_data_TEST_PAA.csv", index_col="Unnamed: 0")

df_train_100 = pd.read_csv(directory + "Approximated/ts_data_TRAIN_100_PAA.csv", index_col="Unnamed: 0")
df_test_100 = pd.read_csv(directory + "Approximated/ts_data_TEST_100_PAA.csv", index_col="Unnamed: 0")


# get ts values
X_train = df_train.values
X_test = df_test.values

X_train_100 = df_train_100.values
X_test_100 = df_test_100.values

# import emotion data
y_train = pd.read_csv(directory + "RavdessAudioOnlyNumpy__Y_train.csv")["emotion"]
y_test = pd.read_csv(directory + "RavdessAudioOnlyNumpy__Y_test.csv")["emotion"]

# check length
assert len(X_train) == len(y_train)
assert len(X_test) == len(y_test)

# %%
# Filter the original DataFrame for speech (1) or song (2)
df_song = df[df["vocal_channel"] == "song"]

# Get the indices of speech and song rows
song_indices = df_song.index

# Filter the time series DataFrames and target variable for speech and song
X_train = df_train.loc[song_indices].values

X_train_100 = df_train_100.loc[song_indices].values

y_train = y_train.loc[song_indices].values

# %%
# plot the audio wave
plt.figure(figsize=(20,5))

for ts in X_train[:10]:
  plt.plot(ts)

plt.show()

# %%
# !pip install tslearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tslearn
#   Downloading tslearn-0.5.3.2-py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.2/358.2 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.56.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.1.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.5.3.2

# %% [markdown]
# ##Baseline

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X_train, y_train)

dummy_clf.predict(X_test)

dummy_clf.score(X_test, y_test)
# Out:
# 0.15384615384615385

# %% [markdown]
# # Shaplet Classifiers

# %%
# Learning-based Approach

# %%
# !pip install tslearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tslearn in /usr/local/lib/python3.10/dist-packages (0.5.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from tslearn) (0.56.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from tslearn) (1.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->tslearn) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->tslearn) (3.1.0)

# %%
from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

# %%
n_ts, ts_sz = X_train.shape
n_classes = len(set(y_train))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 748
# ts_sz 1395
# n_classes 6
# shapelet_sizes {139: 6}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=100,
                        verbose=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/tslearn/shapelets/shapelets.py:354: FutureWarning: The default value for 'scale' is set to False in version 0.4 to ensure backward compatibility, but is likely to change in a future version.
#   warnings.warn("The default value for 'scale' is set to False "

# %%
shp_clf.fit(X_train, y_train)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 12s 78ms/step - loss: 2.2445 - categorical_accuracy: 0.1711 - categorical_crossentropy: 2.1679
# Epoch 2/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2304 - categorical_accuracy: 0.1711 - categorical_crossentropy: 2.1542
# Epoch 3/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2169 - categorical_accuracy: 0.1658 - categorical_crossentropy: 2.1412
# Epoch 4/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2038 - categorical_accuracy: 0.1644 - categorical_crossentropy: 2.1285
# Epoch 5/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.1913 - categorical_accuracy: 0.1644 - categorical_crossentropy: 2.1162
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.1789 - categorical_accuracy: 0.1644 - categorical_crossentropy: 2.1043
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.1672 - categorical_accuracy: 0.1684 - categorical_crossentropy: 2.0929
# Epoch 8/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1557 - categorical_accuracy: 0.1698 - categorical_crossentropy: 2.0818
# Epoch 9/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1446 - categorical_accuracy: 0.1711 - categorical_crossentropy: 2.0710
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1338 - categorical_accuracy: 0.1711 - categorical_crossentropy: 2.0606
# Epoch 11/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1234 - categorical_accuracy: 0.1738 - categorical_crossentropy: 2.0505
# Epoch 12/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.1132 - categorical_accuracy: 0.1751 - categorical_crossentropy: 2.0407
# Epoch 13/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1034 - categorical_accuracy: 0.1711 - categorical_crossentropy: 2.0311
# Epoch 14/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0936 - categorical_accuracy: 0.1738 - categorical_crossentropy: 2.0217
# Epoch 15/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0842 - categorical_accuracy: 0.1765 - categorical_crossentropy: 2.0126
# Epoch 16/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0752 - categorical_accuracy: 0.1751 - categorical_crossentropy: 2.0038
# Epoch 17/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0662 - categorical_accuracy: 0.1778 - categorical_crossentropy: 1.9951
# Epoch 18/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0576 - categorical_accuracy: 0.1832 - categorical_crossentropy: 1.9868
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.0493 - categorical_accuracy: 0.1939 - categorical_crossentropy: 1.9788
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0410 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.9708
# Epoch 21/100
# 3/3 [==============================] - 0s 21ms/step - loss: 2.0331 - categorical_accuracy: 0.2259 - categorical_crossentropy: 1.9631
# Epoch 22/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0254 - categorical_accuracy: 0.2273 - categorical_crossentropy: 1.9556
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0179 - categorical_accuracy: 0.2299 - categorical_crossentropy: 1.9484
# Epoch 24/100
# 3/3 [==============================] - 0s 20ms/step - loss: 2.0105 - categorical_accuracy: 0.2313 - categorical_crossentropy: 1.9413
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0035 - categorical_accuracy: 0.2326 - categorical_crossentropy: 1.9344
# Epoch 26/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9964 - categorical_accuracy: 0.2313 - categorical_crossentropy: 1.9277
# Epoch 27/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9898 - categorical_accuracy: 0.2313 - categorical_crossentropy: 1.9212
# Epoch 28/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9833 - categorical_accuracy: 0.2313 - categorical_crossentropy: 1.9150
# Epoch 29/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9770 - categorical_accuracy: 0.2340 - categorical_crossentropy: 1.9088
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9708 - categorical_accuracy: 0.2353 - categorical_crossentropy: 1.9029
# Epoch 31/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9649 - categorical_accuracy: 0.2353 - categorical_crossentropy: 1.8972
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9592 - categorical_accuracy: 0.2340 - categorical_crossentropy: 1.8917
# Epoch 33/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9536 - categorical_accuracy: 0.2340 - categorical_crossentropy: 1.8863
# Epoch 34/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9482 - categorical_accuracy: 0.2326 - categorical_crossentropy: 1.8810
# Epoch 35/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9429 - categorical_accuracy: 0.2353 - categorical_crossentropy: 1.8760
# Epoch 36/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9379 - categorical_accuracy: 0.2340 - categorical_crossentropy: 1.8711
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.9332 - categorical_accuracy: 0.2286 - categorical_crossentropy: 1.8666
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9284 - categorical_accuracy: 0.2286 - categorical_crossentropy: 1.8620
# Epoch 39/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.9239 - categorical_accuracy: 0.2299 - categorical_crossentropy: 1.8576
# Epoch 40/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9196 - categorical_accuracy: 0.2299 - categorical_crossentropy: 1.8535
# Epoch 41/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9155 - categorical_accuracy: 0.2286 - categorical_crossentropy: 1.8495
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9113 - categorical_accuracy: 0.2259 - categorical_crossentropy: 1.8455
# Epoch 43/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9075 - categorical_accuracy: 0.2233 - categorical_crossentropy: 1.8418
# Epoch 44/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9037 - categorical_accuracy: 0.2246 - categorical_crossentropy: 1.8382
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.9001 - categorical_accuracy: 0.2233 - categorical_crossentropy: 1.8348
# Epoch 46/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8967 - categorical_accuracy: 0.2233 - categorical_crossentropy: 1.8315
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8935 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.8284
# Epoch 48/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8903 - categorical_accuracy: 0.2179 - categorical_crossentropy: 1.8253
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8872 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.8224
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8844 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.8197
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8816 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.8171
# Epoch 52/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8790 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.8146
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8765 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.8122
# Epoch 54/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8742 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.8100
# Epoch 55/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8719 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.8078
# Epoch 56/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.8697 - categorical_accuracy: 0.2166 - categorical_crossentropy: 1.8058
# Epoch 57/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8677 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.8039
# Epoch 58/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8658 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.8021
# Epoch 59/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8640 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.8003
# Epoch 60/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8622 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.7987
# Epoch 61/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8605 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7971
# Epoch 62/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8589 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.7956
# Epoch 63/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8574 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.7942
# Epoch 64/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8560 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.7929
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8547 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.7917
# Epoch 66/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8534 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7905
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8522 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7894
# Epoch 68/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8511 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7884
# Epoch 69/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8501 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.7875
# Epoch 70/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8490 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.7865
# Epoch 71/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8481 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.7856
# Epoch 72/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8472 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.7849
# Epoch 73/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8464 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7841
# Epoch 74/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8456 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7834
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8448 - categorical_accuracy: 0.2086 - categorical_crossentropy: 1.7827
# Epoch 76/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8441 - categorical_accuracy: 0.2086 - categorical_crossentropy: 1.7821
# Epoch 77/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8434 - categorical_accuracy: 0.2086 - categorical_crossentropy: 1.7815
# Epoch 78/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8429 - categorical_accuracy: 0.2086 - categorical_crossentropy: 1.7810
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8422 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7805
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.8416 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.7799
# Epoch 81/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8411 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7795
# Epoch 82/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8406 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7791
# Epoch 83/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8401 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7787
# Epoch 84/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8396 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7783
# Epoch 85/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8393 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7781
# Epoch 86/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8388 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7777
# Epoch 87/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8385 - categorical_accuracy: 0.2086 - categorical_crossentropy: 1.7774
# Epoch 88/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.8380 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7770
# Epoch 89/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.8376 - categorical_accuracy: 0.2099 - categorical_crossentropy: 1.7767
# Epoch 90/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.8373 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7765
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8370 - categorical_accuracy: 0.2152 - categorical_crossentropy: 1.7762
# Epoch 92/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.8367 - categorical_accuracy: 0.2139 - categorical_crossentropy: 1.7760
# Epoch 93/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.8364 - categorical_accuracy: 0.2126 - categorical_crossentropy: 1.7758
# Epoch 94/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8362 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7757
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8359 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7755
# Epoch 96/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8356 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7752
# Epoch 97/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8355 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7752
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.8351 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7749
# Epoch 99/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.8349 - categorical_accuracy: 0.2112 - categorical_crossentropy: 1.7748
# Epoch 100/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.8347 - categorical_accuracy: 0.2086 - categorical_crossentropy: 1.7746
# LearningShapelets(max_iter=100, n_shapelets_per_size={139: 6}, verbose=1,
#                   weight_regularizer=0.01)

# %%
y_pred = shp_clf.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 49ms/step

# %%
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred, zero_division=0, labels=np.unique(y_pred)))
# Out:
# Accuracy 0.16346153846153846
# F1-score [0.07142857 0.27543036 0.         0.03603604 0.05309735 0.
#  0.07751938 0.        ]
#               precision    recall  f1-score   support
#
#        angry       0.25      0.04      0.07        96
#         calm       0.16      0.92      0.28        96
#      fearful       0.13      0.02      0.04        96
#        happy       0.18      0.03      0.05        96
#          sad       0.15      0.05      0.08        96
#
#    micro avg       0.16      0.21      0.18       480
#    macro avg       0.17      0.21      0.10       480
# weighted avg       0.17      0.21      0.10       480

# %%
predict_proba_dist = shp_clf.predict_proba(X_test)
# Out:
# 3/3 [==============================] - 0s 18ms/step

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
pred_probability = []
for eachArr in predict_proba_dist:
    pred_probability.append(softmax(eachArr))

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()

# %%
y_test_encoded = lb.fit_transform(y_test)

# %%
from sklearn.metrics import roc_auc_score
print('ROC-AUC %s' % roc_auc_score(y_test_encoded, pred_probability, multi_class="ovr"))
# Out:
# ROC-AUC 0.5504124359918631

# %% [markdown]
# # Shaplet-distances-based Classifier

# %%
X_train2 = shp_clf.transform(X_train)
# Out:
# 3/3 [==============================] - 0s 21ms/step

# %%
X_train2.shape
# Out:
# (748, 6)

# %%
X_train2
# Out:
# array([[1.9202093e+00, 1.2472766e-03, 1.2120301e+00, 8.5414463e-01,
#         1.5085931e+00, 1.5377506e+00],
#        [1.8951674e+00, 9.6820341e-03, 1.1911323e+00, 7.3637038e-01,
#         1.5219121e+00, 1.2065105e+00],
#        [1.9062165e+00, 9.3443983e-04, 1.2098030e+00, 8.7728155e-01,
#         1.5091090e+00, 1.5572286e+00],
#        ...,
#        [1.0123564e+00, 1.1755888e-03, 7.0527309e-01, 4.7253221e-01,
#         6.5778446e-01, 5.8426279e-01],
#        [1.4865962e+00, 2.2636767e-04, 9.6369243e-01, 4.6432215e-01,
#         9.4864583e-01, 8.3804947e-01],
#        [8.3102548e-01, 2.7493507e-04, 5.5296469e-01, 4.4024375e-01,
#         6.7858559e-01, 5.1508933e-01]], dtype=float32)

# %%
X_test2 = shp_clf.transform(X_test)
# Out:
# 3/3 [==============================] - 0s 21ms/step

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform', metric="euclidean" )
clf.fit(X_train2, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred, zero_division=0, labels=np.unique(y_pred)))
# Out:
# Accuracy 0.15224358974358973
# F1-score [0.19642857 0.27509294 0.         0.10810811 0.09356725 0.02105263
#  0.16346154 0.        ]
#               precision    recall  f1-score   support
#
#        angry       0.17      0.23      0.20        96
#         calm       0.21      0.39      0.28        96
#      fearful       0.11      0.10      0.11        96
#        happy       0.11      0.08      0.09        96
#      neutral       0.02      0.02      0.02        48
#          sad       0.15      0.18      0.16        96
#
#    micro avg       0.15      0.18      0.16       528
#    macro avg       0.13      0.17      0.14       528
# weighted avg       0.14      0.18      0.15       528

# %%
predict_proba_dist = clf.predict_proba(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train2, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e3692c1c253c> in <cell line: 2>()
#       1 clf = DecisionTreeClassifier(max_depth=8, random_state=42)
# ----> 2 clf.fit(X_train2, y_train)
#       3
#       4 y_pred = clf.predict(X_test2)
#       5
#
# NameError: name 'X_train2' is not defined

# %% [markdown]
# # Feature-based Classifier

# %%
import scipy.stats as stats

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
X_train3 = np.array([list(calculate_features(x).values()) for x in X_train])

# %%
X_train3.shape
# Out:
# (748, 13)

# %%
X_train3
# Out:
# array([[-6.09550565e-05,  6.18978903e-01,  3.83134882e-01, ...,
#         -9.84767918e-05,  2.35994896e-01,  1.39503512e+00],
#        [ 4.68116713e-05,  6.70110757e-01,  4.49048426e-01, ...,
#          6.98566182e-05, -1.38935670e+00,  5.15828534e+00],
#        [ 2.17489103e-04,  6.31389297e-01,  3.98652445e-01, ...,
#          3.44461182e-04, -4.87287438e-01,  2.30304711e+00],
#        ...,
#        [ 3.54302924e-04,  9.91692364e-01,  9.83453745e-01, ...,
#          3.57271001e-04, -2.03975961e+00,  9.42568161e+00],
#        [-2.32101805e-04,  9.80838040e-01,  9.62043260e-01, ...,
#         -2.36636218e-04, -6.54394350e-01,  1.59965205e+01],
#        [-2.75145383e-04,  9.70855296e-01,  9.42560005e-01, ...,
#         -2.83405142e-04, -3.89209606e+00,  2.81334705e+01]])

# %%
X_test3 = np.array([list(calculate_features(x).values()) for x in X_test])

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train3, y_train)

y_pred = clf.predict(X_test3)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred, zero_division=0, labels=np.unique(y_pred)))
# Out:
# Accuracy 0.20192307692307693
# F1-score [0.2231405  0.22222222 0.         0.13605442 0.22857143 0.36363636
#  0.20233463 0.        ]
#               precision    recall  f1-score   support
#
#        angry       0.18      0.28      0.22        96
#         calm       0.18      0.28      0.22        96
#      fearful       0.20      0.10      0.14        96
#        happy       0.25      0.21      0.23        96
#      neutral       0.40      0.33      0.36        48
#          sad       0.16      0.27      0.20        96
#
#    micro avg       0.20      0.24      0.22       528
#    macro avg       0.23      0.25      0.23       528
# weighted avg       0.21      0.24      0.22       528

# %%
predict_proba_dist = clf.predict_proba(X_test3)

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
pred_probability = []
for eachArr in predict_proba_dist:
    pred_probability.append(softmax(eachArr))

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()

# %%
y_test_encoded = lb.fit_transform(y_test)

# %%
from sklearn.metrics import roc_auc_score
print('ROC-AUC %s' % roc_auc_score(y_test_encoded, pred_probability, multi_class="ovr"))
# Out:
# ROC-AUC 0.4917819689955107

# %% [markdown]
# # Time Series Classifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform', metric="euclidean" )
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
#print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred, zero_division=0, labels=np.unique(y_pred)))
# Out:
# Accuracy 0.15224358974358973
# F1-score [0.17894737 0.22626263 0.         0.1        0.11180124 0.0625
#  0.08196721 0.        ]
#               precision    recall  f1-score   support
#
#        angry       0.18      0.18      0.18        96
#         calm       0.14      0.58      0.23        96
#      fearful       0.25      0.06      0.10        96
#        happy       0.14      0.09      0.11        96
#      neutral       0.12      0.04      0.06        48
#          sad       0.19      0.05      0.08        96
#
#    micro avg       0.15      0.18      0.16       528
#    macro avg       0.17      0.17      0.13       528
# weighted avg       0.18      0.18      0.13       528

# %%
predict_proba_dist = clf.predict_proba(X_test)

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
pred_probability = []
for eachArr in predict_proba_dist:
    pred_probability.append(softmax(eachArr))

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()

# %%
y_test_encoded = lb.fit_transform(y_test)

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
print('ROC-AUC %s' % roc_auc_score(y_test_encoded, pred_probability, multi_class="ovr"))
# Out:
# ROC-AUC 0.5197044226992144

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred, zero_division=0, labels=np.unique(y_pred)))
# Out:
# Accuracy 0.17147435897435898
# F1-score [0.23041475 0.20242915 0.         0.13       0.1595092  0.10810811
#  0.21513944 0.        ]
#               precision    recall  f1-score   support
#
#        angry       0.21      0.26      0.23        96
#         calm       0.17      0.26      0.20        96
#      fearful       0.12      0.14      0.13        96
#        happy       0.19      0.14      0.16        96
#      neutral       0.15      0.08      0.11        48
#          sad       0.17      0.28      0.22        96
#
#    micro avg       0.17      0.20      0.19       528
#    macro avg       0.17      0.19      0.17       528
# weighted avg       0.17      0.20      0.18       528

# %%
# !pip install pyts
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyts
#   Downloading pyts-0.12.0-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.22.4)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.2.0)
# Requirement already satisfied: numba>=0.48.0 in /usr/local/lib/python3.10/dist-packages (from pyts) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.48.0->pyts) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.48.0->pyts) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.1->pyts) (3.1.0)
# Installing collected packages: pyts
# Successfully installed pyts-0.12.0

# %%
from pyts.classification import KNeighborsClassifier

# %%
#USO IL DATASET RIDOTTO PERCHE' IMPIEGA TROPPO TEMPO CON L'ORIGINALE
clf = KNeighborsClassifier(metric='dtw_sakoechiba')
clf.fit(X_train_100, y_train)

y_pred = clf.predict(X_test_100)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.1907051282051282
# F1-score [0.24444444 0.24561404 0.1372549  0.14130435 0.19626168 0.10526316
#  0.22335025 0.15238095]
#               precision    recall  f1-score   support
#
#        angry       0.26      0.23      0.24        96
#         calm       0.28      0.22      0.25        96
#      disgust       0.13      0.15      0.14        48
#      fearful       0.15      0.14      0.14        96
#        happy       0.18      0.22      0.20        96
#      neutral       0.11      0.10      0.11        48
#          sad       0.22      0.23      0.22        96
#    surprised       0.14      0.17      0.15        48
#
#     accuracy                           0.19       624
#    macro avg       0.18      0.18      0.18       624
# weighted avg       0.20      0.19      0.19       624

# %% [markdown]
# # CNN Classifier

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling1D
from keras.layers import Conv1D, Activation, Conv1D, BatchNormalization

# %%
def build_simple_cnn(n_timesteps, n_outputs):
    model = Sequential()

    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, 1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.3))

    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.3))

    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.3))

    model.add(GlobalAveragePooling1D())

    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
from sklearn.model_selection import train_test_split
X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_cnn = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train_cnn, y_train, test_size=0.2, stratify=y_train)

n_timesteps, n_outputs, n_features = X_train_cnn.shape[1], len(np.unique(y_train_cnn)), 1
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
# Out:
# TIMESTEPS:  1395
# N. LABELS:  6

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
y_train_cnn = encoder.fit_transform(y_train_cnn)
y_val_cnn = encoder.fit_transform(y_val_cnn)
y_test = encoder.fit_transform(y_test)

y_val_cnn
# Out:
# array([3, 3, 2, 1, 1, 3, 2, 4, 1, 0, 0, 1, 5, 2, 0, 2, 2, 3, 5, 3, 2, 1,
#        1, 1, 3, 0, 1, 0, 1, 3, 5, 5, 5, 0, 5, 0, 0, 1, 3, 5, 4, 1, 1, 4,
#        3, 0, 2, 5, 5, 2, 3, 3, 3, 2, 2, 2, 5, 1, 0, 5, 1, 0, 2, 5, 2, 5,
#        5, 0, 3, 2, 5, 4, 3, 0, 1, 1, 0, 0, 4, 4, 3, 3, 5, 5, 1, 3, 3, 5,
#        0, 3, 1, 2, 4, 1, 1, 1, 0, 2, 1, 5, 2, 4, 3, 2, 3, 2, 2, 0, 2, 0,
#        3, 0, 5, 1, 2, 4, 3, 1, 4, 1, 3, 5, 4, 0, 2, 1, 4, 5, 4, 4, 5, 3,
#        0, 2, 0, 1, 5, 2, 5, 3, 0, 2, 3, 1, 0, 5, 2, 5, 0, 0])

# %%
cnn = build_simple_cnn(n_timesteps, n_outputs)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1388, 16)          144
#
#  batch_normalization (BatchN  (None, 1388, 16)         64
#  ormalization)
#
#  activation (Activation)     (None, 1388, 16)          0
#
#  dropout (Dropout)           (None, 1388, 16)          0
#
#  conv1d_1 (Conv1D)           (None, 1384, 32)          2592
#
#  batch_normalization_1 (Batc  (None, 1384, 32)         128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1384, 32)          0
#
#  dropout_1 (Dropout)         (None, 1384, 32)          0
#
#  conv1d_2 (Conv1D)           (None, 1382, 64)          6208
#
#  batch_normalization_2 (Batc  (None, 1382, 64)         256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1382, 64)          0
#
#  dropout_2 (Dropout)         (None, 1382, 64)          0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 6)                 390
#
# =================================================================
# Total params: 9,782
# Trainable params: 9,558
# Non-trainable params: 224
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train_cnn.shape[0]/10, batch_size))

# %%
history_cnn = cnn.fit(X_train_cnn, y_train_cnn, epochs=5, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Epoch 1/5
# 38/38 [==============================] - 6s 20ms/step - loss: 1.7612 - accuracy: 0.2207 - val_loss: 1.7698 - val_accuracy: 0.1933 - lr: 0.0010
# Epoch 2/5
# 38/38 [==============================] - 0s 11ms/step - loss: 1.6627 - accuracy: 0.2876 - val_loss: 1.7501 - val_accuracy: 0.1933 - lr: 0.0010
# Epoch 3/5
# 38/38 [==============================] - 0s 10ms/step - loss: 1.6108 - accuracy: 0.3278 - val_loss: 1.7410 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 4/5
# 38/38 [==============================] - 0s 10ms/step - loss: 1.5468 - accuracy: 0.3796 - val_loss: 1.7233 - val_accuracy: 0.2200 - lr: 0.0010
# Epoch 5/5
# 38/38 [==============================] - 0s 13ms/step - loss: 1.5114 - accuracy: 0.3980 - val_loss: 1.7049 - val_accuracy: 0.2467 - lr: 0.0010

# %%
y_pred = np.argmax(cnn.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred, zero_division=0, labels=np.unique(y_pred)))
# Out:
# 20/20 [==============================] - 0s 4ms/step
# Accuracy 0.1762820512820513
# F1-score [0.29490617 0.26751592 0.03921569 0.04137931 0.         0.15929204
#  0.         0.        ]
#               precision    recall  f1-score   support
#
#            0       0.20      0.57      0.29        96
#            1       0.19      0.44      0.27        96
#            2       0.33      0.02      0.04        48
#            3       0.06      0.03      0.04        96
#            4       0.00      0.00      0.00        96
#            5       0.14      0.19      0.16        48
#
#    micro avg       0.18      0.23      0.20       480
#    macro avg       0.15      0.21      0.13       480
# weighted avg       0.14      0.23      0.14       480

# %%
cnn.evaluate(X_test_cnn, y_test)
# Out:
# 20/20 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1763
# [nan, 0.17628204822540283]

# %%
predict_proba_dist = clf.predict_proba(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-7c555248e19e> in <cell line: 1>()
# ----> 1 predict_proba_dist = clf.predict_proba(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in predict_proba(self, X, check_input)
#     920         """
#     921         check_is_fitted(self)
# --> 922         X = self._validate_X_predict(X, check_input)
#     923         proba = self.tree_.predict(X)
#     924
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     390         """Validate the training data on predict (probabilities)."""
#     391         if check_input:
# --> 392             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     393             if issparse(X) and (
#     394                 X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     586
#     587         if not no_val_X and check_params.get("ensure_2d", True):
# --> 588             self._check_n_features(X, reset=reset)
#     589
#     590         return out
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _check_n_features(self, X, reset)
#     387
#     388         if n_features != self.n_features_in_:
# --> 389             raise ValueError(
#     390                 f"X has {n_features} features, but {self.__class__.__name__} "
#     391                 f"is expecting {self.n_features_in_} features as input."
#
# ValueError: X has 1395 features, but DecisionTreeClassifier is expecting 13 features as input.

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
pred_probability = []
for eachArr in predict_proba_dist:
    pred_probability.append(softmax(eachArr))

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()

# %%
y_test_encoded = lb.fit_transform(y_test)

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
print('ROC-AUC %s' % roc_auc_score(y_test_encoded, pred_probability, multi_class="ovr"))

# %% [markdown]
# # LSTM Classifier

# %%
from keras.layers import LSTM

# %%
def build_lstm(n_timesteps, n_outputs):
    model = Sequential()
    model.add(LSTM(256, input_shape=(n_timesteps, 1)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='sigmoid'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
lstm = build_lstm(n_timesteps, n_outputs)

# %%
lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 281,160
# Trainable params: 281,160
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm = cnn.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=mini_batch_size, callbacks=callbacks,
                       validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Epoch 1/10
# 92/92 [==============================] - 1s 9ms/step - loss: 1.8694 - accuracy: 0.2750 - val_loss: 1.9143 - val_accuracy: 0.2596 - lr: 0.0010
# Epoch 2/10
# 92/92 [==============================] - 1s 12ms/step - loss: 1.8584 - accuracy: 0.2722 - val_loss: 1.8931 - val_accuracy: 0.2760 - lr: 0.0010
# Epoch 3/10
# 92/92 [==============================] - 1s 12ms/step - loss: 1.8401 - accuracy: 0.2914 - val_loss: 1.8868 - val_accuracy: 0.2760 - lr: 0.0010
# Epoch 4/10
# 92/92 [==============================] - 1s 12ms/step - loss: 1.8233 - accuracy: 0.2948 - val_loss: 1.8601 - val_accuracy: 0.3115 - lr: 0.0010
# Epoch 5/10
# 92/92 [==============================] - 1s 11ms/step - loss: 1.7940 - accuracy: 0.2907 - val_loss: 1.8428 - val_accuracy: 0.3087 - lr: 0.0010
# Epoch 6/10
# 92/92 [==============================] - 1s 8ms/step - loss: 1.7882 - accuracy: 0.3133 - val_loss: 1.8346 - val_accuracy: 0.3361 - lr: 0.0010
# Epoch 7/10
# 92/92 [==============================] - 1s 8ms/step - loss: 1.7682 - accuracy: 0.3263 - val_loss: 1.8089 - val_accuracy: 0.3251 - lr: 0.0010
# Epoch 8/10
# 92/92 [==============================] - 1s 8ms/step - loss: 1.7492 - accuracy: 0.3269 - val_loss: 1.7837 - val_accuracy: 0.3306 - lr: 0.0010
# Epoch 9/10
# 92/92 [==============================] - 1s 8ms/step - loss: 1.7375 - accuracy: 0.3167 - val_loss: 1.7706 - val_accuracy: 0.3470 - lr: 0.0010
# Epoch 10/10
# 92/92 [==============================] - 1s 8ms/step - loss: 1.7159 - accuracy: 0.3393 - val_loss: 1.7887 - val_accuracy: 0.3306 - lr: 0.0010

# %%
y_pred = np.argmax(lstm.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 1s 30ms/step
# Accuracy 0.13942307692307693
# F1-score [0.         0.13636364 0.         0.18562874 0.         0.
#  0.22166247 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        96
#            1       0.15      0.12      0.14        96
#            2       0.00      0.00      0.00        48
#            3       0.13      0.32      0.19        96
#            4       0.00      0.00      0.00        96
#            5       0.00      0.00      0.00        48
#            6       0.15      0.46      0.22        96
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.14       624
#    macro avg       0.05      0.11      0.07       624
# weighted avg       0.07      0.14      0.08       624
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
lstm.evaluate(X_test_cnn, y_test)
# Out:
# 20/20 [==============================] - 1s 27ms/step - loss: 2.0794 - accuracy: 0.1394
# [2.07938289642334, 0.13942307233810425]

# %% [markdown]
# # Multivariate Time Series Classifiers

# %%
from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
scaler = TimeSeriesScalerMinMax()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train.shape
# Out:
# (1828,)

# %%
y_train
# Out:
# 0         neutral
# 1         neutral
# 2         neutral
# 3         neutral
# 4            calm
#           ...
# 1823    surprised
# 1824    surprised
# 1825    surprised
# 1826    surprised
# 1827    surprised
# Name: emotion, Length: 1828, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
print("Original X_train shape:", X_train.shape)
print("Original X_test shape:", X_test.shape)
# Out:
# Original X_train shape: (1828, 1395, 1)
# Original X_test shape: (624, 1395, 1)

# %%
num_train_samples = X_train.shape[0]
num_test_samples = X_test.shape[0]

time_steps = 45
features_per_step = 31

X_train_reshaped = X_train.reshape(num_train_samples, time_steps, features_per_step)
X_test_reshaped = X_test.reshape(num_test_samples, time_steps, features_per_step)

# %%
X_train_reshaped = X_train.reshape(num_train_samples, time_steps, features_per_step)

n_timesteps, n_outputs, n_features = X_train_reshaped.shape[1], len(np.unique(y_train)), X_train_reshaped.shape[2]
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
print("N. FEATURES: ", n_features)
# Out:
# TIMESTEPS:  45
# N. LABELS:  8
# N. FEATURES:  31

# %%
X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers import TimeDistributed
from keras.layers import LSTM
from keras.layers import Dense, Conv1D, Conv2D, MaxPool2D, Flatten, Dropout, LeakyReLU, GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
def build_lstm2(n_timesteps, n_outputs, n_features):
    model = Sequential()
    model.add(LSTM(4, input_shape=(n_timesteps, n_features), return_sequences=True,
                        kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.3))

    #1
    for _ in range(2):
        model.add(LSTM(4, kernel_initializer='TruncatedNormal', return_sequences=True))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.04))

    #2
    model.add(LSTM(32, kernel_initializer='TruncatedNormal', return_sequences=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))

    #3
    for _ in range(2):
        model.add(Dense(256, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))
    #4
    for _ in range(1):
        model.add(Dense(64, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.7))

    #5
    model.add(Dense(32, kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.4))

    model.add(Dense(n_outputs, activation='sigmoid'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
lstm2 = build_lstm2(n_timesteps, n_outputs, n_features)

# %%
lstm2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 45, 4)             576
#
#  batch_normalization_3 (Batc  (None, 45, 4)            16
#  hNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 45, 4)             0
#
#  dropout_5 (Dropout)         (None, 45, 4)             0
#
#  lstm_2 (LSTM)               (None, 45, 4)             144
#
#  batch_normalization_4 (Batc  (None, 45, 4)            16
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 45, 4)             0
#
#  dropout_6 (Dropout)         (None, 45, 4)             0
#
#  lstm_3 (LSTM)               (None, 45, 4)             144
#
#  batch_normalization_5 (Batc  (None, 45, 4)            16
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 45, 4)             0
#
#  dropout_7 (Dropout)         (None, 45, 4)             0
#
#  lstm_4 (LSTM)               (None, 32)                4736
#
#  batch_normalization_6 (Batc  (None, 32)               128
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32)                0
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 256)               8448
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 256)               0
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  batch_normalization_8 (Batc  (None, 256)              1024
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 256)               0
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 64)                16448
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 64)                0
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  batch_normalization_10 (Bat  (None, 32)               128
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32)                0
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 101,240
# Trainable params: 99,936
# Non-trainable params: 1,304
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_lstm2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
lstm2 = build_lstm2(n_timesteps, n_outputs, n_features)

# Recompile the model
lstm2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Fit the model with the reshaped data
history_lstm2 = lstm2.fit(X_train_reshaped, y_train, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                          validation_data=(X_test_reshaped, y_test)).history
# Out:
# Epoch 1/50
# 115/115 [==============================] - 28s 34ms/step - loss: 2.3758 - accuracy: 0.1433 - val_loss: 2.0656 - val_accuracy: 0.1538 - lr: 0.0010
# Epoch 2/50
# 115/115 [==============================] - 3s 23ms/step - loss: 2.2845 - accuracy: 0.1351 - val_loss: 2.0499 - val_accuracy: 0.1538 - lr: 0.0010
# Epoch 3/50
# 115/115 [==============================] - 3s 30ms/step - loss: 2.1850 - accuracy: 0.1477 - val_loss: 2.0421 - val_accuracy: 0.1538 - lr: 0.0010
# Epoch 4/50
# 115/115 [==============================] - 3s 25ms/step - loss: 2.1261 - accuracy: 0.1816 - val_loss: 2.0326 - val_accuracy: 0.1651 - lr: 0.0010
# Epoch 5/50
# 115/115 [==============================] - 3s 23ms/step - loss: 2.1077 - accuracy: 0.1647 - val_loss: 2.0281 - val_accuracy: 0.1635 - lr: 0.0010
# Epoch 6/50
# 115/115 [==============================] - 2s 21ms/step - loss: 2.0792 - accuracy: 0.1783 - val_loss: 2.0318 - val_accuracy: 0.1635 - lr: 0.0010
# Epoch 7/50
# 115/115 [==============================] - 3s 22ms/step - loss: 2.0544 - accuracy: 0.1931 - val_loss: 2.0312 - val_accuracy: 0.1891 - lr: 0.0010
# Epoch 8/50
# 115/115 [==============================] - 3s 29ms/step - loss: 2.0343 - accuracy: 0.1794 - val_loss: 2.0382 - val_accuracy: 0.1827 - lr: 0.0010
# Epoch 9/50
# 115/115 [==============================] - 3s 25ms/step - loss: 2.0278 - accuracy: 0.1937 - val_loss: 2.0225 - val_accuracy: 0.1859 - lr: 0.0010
# Epoch 10/50
# 115/115 [==============================] - 3s 22ms/step - loss: 2.0076 - accuracy: 0.1980 - val_loss: 1.9975 - val_accuracy: 0.2019 - lr: 0.0010
# Epoch 11/50
# 115/115 [==============================] - 3s 22ms/step - loss: 2.0206 - accuracy: 0.1915 - val_loss: 2.0006 - val_accuracy: 0.2147 - lr: 0.0010
# Epoch 46/50
# 115/115 [==============================] - 3s 23ms/step - loss: 1.8594 - accuracy: 0.2511 - val_loss: 1.9347 - val_accuracy: 0.2147 - lr: 0.0010
# Epoch 47/50
# 115/115 [==============================] - 3s 23ms/step - loss: 1.8599 - accuracy: 0.2681 - val_loss: 1.9405 - val_accuracy: 0.2356 - lr: 0.0010
# Epoch 48/50
# 115/115 [==============================] - 3s 30ms/step - loss: 1.8529 - accuracy: 0.2691 - val_loss: 2.0255 - val_accuracy: 0.2115 - lr: 0.0010
# Epoch 49/50
# 115/115 [==============================] - 2s 21ms/step - loss: 1.8601 - accuracy: 0.2795 - val_loss: 1.9195 - val_accuracy: 0.2436 - lr: 0.0010
# Epoch 50/50
# 115/115 [==============================] - 3s 23ms/step - loss: 1.8553 - accuracy: 0.2664 - val_loss: 1.9153 - val_accuracy: 0.2372 - lr: 0.0010

# %%
y_pred = np.argmax(lstm2.predict(X_test_reshaped), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 2s 10ms/step
# Accuracy 0.23717948717948717
# F1-score [0.33043478 0.43939394 0.         0.10852713 0.11940299 0.06557377
#  0.20958084 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.28      0.40      0.33        96
#            1       0.35      0.60      0.44        96
#            2       0.00      0.00      0.00        48
#            3       0.21      0.07      0.11        96
#            4       0.21      0.08      0.12        96
#            5       0.15      0.04      0.07        48
#            6       0.15      0.36      0.21        96
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.24       624
#    macro avg       0.17      0.20      0.16       624
# weighted avg       0.20      0.24      0.19       624
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train_cnn.shape
# Out:
# (1462, 1395, 1)

# %%
print("X_train_cnn shape:", X_train_cnn.shape)
print("X_val_cnn shape:", X_val_cnn.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train_cnn shape: (1462, 1395, 1)
# X_val_cnn shape: (366, 1395, 1)
# X_test shape: (624, 1395, 1)

# %%
X_train_cnn2 = X_train_cnn.reshape(X_train_cnn.shape[0], X_train_cnn.shape[1], 1)
X_val_cnn2 = X_val_cnn.reshape(X_val_cnn.shape[0], X_val_cnn.shape[1], 1)
X_test_cnn2 = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
import numpy as np

X_train_cnn2 = np.reshape(X_train_cnn, (X_train_cnn.shape[0], 45, 31, 1))
X_val_cnn2 = np.reshape(X_val_cnn, (X_val_cnn.shape[0], 45, 31, 1))
X_test_cnn2 = np.reshape(X_test, (X_test.shape[0], 45, 31, 1))

# %%
def build_cnn2(n_timesteps, n_features, n_outputs):
    input_shape = (n_timesteps, n_features, 1)

    model = Sequential()

    ks1_first = 3
    ks1_second = 3

    ks2_first = 4
    ks2_second = 4

    model.add(Conv2D(filters=(3),
                     kernel_size=(ks1_first, ks1_second),
                     input_shape=input_shape,
                     padding='same',
                     kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.02))

    for _ in range(2):
        model.add(Conv2D(filters=(4),
                     kernel_size= (ks2_first, ks2_second),
                         padding='same',
                     kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))

    model.add(Flatten())

    for _ in range(4):
        model.add(Dense(64 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.4))

    for _ in range(3):
        model.add(Dense(128 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.3))

    model.add(Dense(1024 , kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))

    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
cnn2 = build_cnn2(n_timesteps, n_features, n_outputs)

# %%
cnn2.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 45, 31, 3)         30
#
#  batch_normalization_30 (Bat  (None, 45, 31, 3)        12
#  chNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 45, 31, 3)         0
#
#  dropout_32 (Dropout)        (None, 45, 31, 3)         0
#
#  conv2d_4 (Conv2D)           (None, 45, 31, 4)         196
#
#  batch_normalization_31 (Bat  (None, 45, 31, 4)        16
#  chNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 45, 31, 4)         0
#
#  dropout_33 (Dropout)        (None, 45, 31, 4)         0
#
#  conv2d_5 (Conv2D)           (None, 45, 31, 4)         260
#
#  batch_normalization_32 (Bat  (None, 45, 31, 4)        16
#  chNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 45, 31, 4)         0
#
#  dropout_34 (Dropout)        (None, 45, 31, 4)         0
#
#  flatten_7 (Flatten)         (None, 5580)              0
#
#  dense_34 (Dense)            (None, 64)                357184
#
#  batch_normalization_33 (Bat  (None, 64)               256
#  chNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 64)                0
#
#  dropout_35 (Dropout)        (None, 64)                0
#
#  dense_35 (Dense)            (None, 64)                4160
#
#  batch_normalization_34 (Bat  (None, 64)               256
#  chNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 64)                0
#
#  dropout_36 (Dropout)        (None, 64)                0
#
#  dense_36 (Dense)            (None, 64)                4160
#
#  batch_normalization_35 (Bat  (None, 64)               256
#  chNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 64)                0
#
#  dropout_37 (Dropout)        (None, 64)                0
#
#  dense_37 (Dense)            (None, 64)                4160
#
#  batch_normalization_36 (Bat  (None, 64)               256
#  chNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 64)                0
#
#  dropout_38 (Dropout)        (None, 64)                0
#
#  dense_38 (Dense)            (None, 128)               8320
#
#  batch_normalization_37 (Bat  (None, 128)              512
#  chNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 128)               0
#
#  dropout_39 (Dropout)        (None, 128)               0
#
#  dense_39 (Dense)            (None, 128)               16512
#
#  batch_normalization_38 (Bat  (None, 128)              512
#  chNormalization)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 128)               0
#
#  dropout_40 (Dropout)        (None, 128)               0
#
#  dense_40 (Dense)            (None, 128)               16512
#
#  batch_normalization_39 (Bat  (None, 128)              512
#  chNormalization)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 128)               0
#
#  dropout_41 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 1024)              132096
#
#  batch_normalization_40 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 1024)              0
#
#  dropout_42 (Dropout)        (None, 1024)              0
#
#  dense_42 (Dense)            (None, 8)                 8200
#
# =================================================================
# Total params: 558,490
# Trainable params: 555,140
# Non-trainable params: 3,350
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(1395, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
history_cnn2 = cnn2.fit(X_train_cnn2, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                        validation_data=(X_val_cnn2, y_val_cnn)).history
# Out:
# Epoch 1/50
# 92/92 [==============================] - 37s 22ms/step - loss: 3.1401 - accuracy: 0.1518 - val_loss: 2.0594 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 2/50
# 92/92 [==============================] - 2s 18ms/step - loss: 3.0540 - accuracy: 0.1306 - val_loss: 2.0795 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 3/50
# 92/92 [==============================] - 2s 19ms/step - loss: 2
50
# 92/92 [==============================] - 1s 14ms/step - loss: 1.7219 - accuracy: 0.3427 - val_loss: 2.0964 - val_accuracy: 0.2077 - lr: 0.0010
# Epoch 46/50
# 92/92 [==============================] - 1s 14ms/step - loss: 1.6979 - accuracy: 0.3434 - val_loss: 2.1317 - val_accuracy: 0.2568 - lr: 0.0010
# Epoch 47/50
# 92/92 [==============================] - 1s 14ms/step - loss: 1.6659 - accuracy: 0.3591 - val_loss: 2.1293 - val_accuracy: 0.2350 - lr: 0.0010
# Epoch 48/50
# 92/92 [==============================] - 1s 13ms/step - loss: 1.6975 - accuracy: 0.3523 - val_loss: 2.1892 - val_accuracy: 0.2077 - lr: 0.0010
# Epoch 49/50
# 92/92 [==============================] - 1s 14ms/step - loss: 1.6552 - accuracy: 0.3659 - val_loss: 2.1216 - val_accuracy: 0.2158 - lr: 0.0010
# Epoch 50/50
# 92/92 [==============================] - 2s 19ms/step - loss: 1.6343 - accuracy: 0.3598 - val_loss: 2.2064 - val_accuracy: 0.2240 - lr: 0.0010

# %%
y_pred = np.argmax(cnn2.predict(X_test_cnn2), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 5ms/step
# Accuracy 0.20833333333333334
# F1-score [0.20809249 0.37121212 0.12727273 0.1871345  0.21395349 0.03448276
#  0.12435233 0.125     ]
#               precision    recall  f1-score   support
#
#            0       0.23      0.19      0.21        96
#            1       0.29      0.51      0.37        96
#            2       0.11      0.15      0.13        48
#            3       0.21      0.17      0.19        96
#            4       0.19      0.24      0.21        96
#            5       0.10      0.02      0.03        48
#            6       0.12      0.12      0.12        96
#            7       0.25      0.08      0.12        48
#
#     accuracy                           0.21       624
#    macro avg       0.19      0.18      0.17       624
# weighted avg       0.20      0.21      0.19       624

# %%
def build_cnn3(n_timesteps, n_outputs, n_features):
    model = Sequential()

    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, n_features)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.3))

    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.3))

    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Dropout(0.3))

    model.add(GlobalAveragePooling1D())

    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
cnn3 = build_cnn3(n_timesteps, n_outputs, n_features)

# %%
cnn3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 38, 16)            3984
#
#  batch_normalization (BatchN  (None, 38, 16)           64
#  ormalization)
#
#  activation (Activation)     (None, 38, 16)            0
#
#  dropout (Dropout)           (None, 38, 16)            0
#
#  conv1d_1 (Conv1D)           (None, 34, 32)            2592
#
#  batch_normalization_1 (Batc  (None, 34, 32)           128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 34, 32)            0
#
#  dropout_1 (Dropout)         (None, 34, 32)            0
#
#  conv1d_2 (Conv1D)           (None, 32, 64)            6208
#
#  batch_normalization_2 (Batc  (None, 32, 64)           256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 32, 64)            0
#
#  dropout_2 (Dropout)         (None, 32, 64)            0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                 520
#
# =================================================================
# Total params: 13,752
# Trainable params: 13,528
# Non-trainable params: 224
# _________________________________________________________________

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn3 = cnn3.fit(X_train_cnn2, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                        validation_data=(X_val_cnn2, y_val_cnn)).history
# Out:
# Epoch 1/50
# 92/92 [==============================] - 14s 14ms/step - loss: 2.0934 - accuracy: 0.1498 - val_loss: 2.0704 - val_accuracy: 0.1421 - lr: 0.0010
# Epoch 2/50
# 92/92 [==============================] - 1s 13ms/step - loss: 2.0248 - accuracy: 0.1943 - val_loss: 2.0756 - val_accuracy: 0.1557 - lr: 0.0010
# Epoch 3/50
# 92/92 [==============================] - 1s 12ms/step - loss: 1.9954 - accuracy: 0.2011 - val_loss: 2.0769 - val_accuracy: 0.1557 - lr: 0.0010
# Epoch 4/50
# 92/92 [==============================] - 1s 12ms/step - loss: 1.9613 - accuracy: 0.2250 - val_loss: 2.3510 - val_accuracy: 0.0929 - lr: 0.0010
# Epoch 5/50
# 92/92 [==============================] - 1s 10ms/step - loss: 1.9361 - accuracy: 0.2456 - val_loss: 2.0401 - val_accuracy: 0.1612 - lr: 0.0010
# Epoch 6/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.9281 - accuracy: 0.2373 - val_loss: 3.1457 - val_accuracy: 0.1585 - lr: 0.0010
# Epoch 7/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.9235 - accuracy: 0.2647 - val_loss: 3.8299 - val_accuracy: 0.1557 - lr: 0.0010
# Epoch 8/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.9075 - accuracy: 0.2592 - val_loss: 3.0625 - val_accuracy: 0.0929 - lr: 0.0010
# Epoch 9/50
# 92/92 [==============================] - 1s 11ms/step - loss: 1.9101 - accuracy: 0.2640 - val_loss: 2.0846 - val_accuracy: 0.1858 - lr: 0.0010
# Epoch 10/50
# 92/92 [==============================] - 1s 9ms/step - loss: 1.8948 - accuracy: 0.2736 - val_loss: 2.3166 - val_accuracy: 0.1503 - lr: 0.0010
# Epoch 11/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8949 - accuracy: 0.2640 - val_loss: 2.3795 - val_accuracy: 0.1885 - lr: 0.0010
# Epoch 12/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8481 - accuracy: 0.2825 - val_loss: 3.3749 - val_accuracy: 0.0929 - lr: 0.0010
# Epoch 13/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8484 - accuracy: 0.2880 - val_loss: 2.4240 - val_accuracy: 0.1011 - lr: 0.0010
# Epoch 14/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8601 - accuracy: 0.2839 - val_loss: 2.0872 - val_accuracy: 0.1475 - lr: 0.0010
# Epoch 15/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8397 - accuracy: 0.2927 - val_loss: 4.8628 - val_accuracy: 0.1366 - lr: 0.0010
# Epoch 16/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8429 - accuracy: 0.2873 - val_loss: 2.9814 - val_accuracy: 0.0956 - lr: 0.0010
# Epoch 17/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.8373 - accuracy: 0.2866 - val_loss: 2.1597 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 18/50
# 92/92 [==============================] - 1s 14ms/step - loss: 1.8370 - accuracy: 0.2715 - val_loss: 2.0758 - val_accuracy: 0.1885 - lr: 0.0010
# Epoch 19/50
# 92/92 [==============================] - 1s 13ms/step - loss: 1.8190 - accuracy: 0.2927 - val_loss: 1.9821 - val_accuracy: 0.2104 - lr: 0.0010
# Epoch 20/50
# 92/92 [==============================] - 1s 13ms/step - loss: 1.8244 - accuracy: 0.2873 - val_loss: 1.9797 - val_accuracy: 0.2377 - lr: 0.0010
# Epoch 21/50
# 92/92 [==============================] - 1s 10ms/step - loss: 1.8191 - accuracy: 0.2934 - val_loss: 3.5576 - val_accuracy: 0.0847 - lr: 0.0010
# Epoch 22/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.7868 - accuracy: 0.3071 - val_loss: 2.1881 - val_accuracy: 0.1612 - lr: 0.0010
# Epoch 23/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.
- val_accuracy: 0.1530 - lr: 0.0010
# Epoch 47/50
# 92/92 [==============================] - 1s 9ms/step - loss: 1.6927 - accuracy: 0.3557 - val_loss: 2.0533 - val_accuracy: 0.2104 - lr: 0.0010
# Epoch 48/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.6736 - accuracy: 0.3543 - val_loss: 2.0770 - val_accuracy: 0.2049 - lr: 0.0010
# Epoch 49/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.6998 - accuracy: 0.3304 - val_loss: 1.9748 - val_accuracy: 0.2514 - lr: 0.0010
# Epoch 50/50
# 92/92 [==============================] - 1s 8ms/step - loss: 1.6783 - accuracy: 0.3495 - val_loss: 2.0632 - val_accuracy: 0.2131 - lr: 0.0010

# %%
y_pred = np.argmax(cnn3.predict(X_test_reshaped), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 20/20 [==============================] - 0s 3ms/step
# Accuracy 0.20192307692307693
# F1-score [0.3099631  0.06       0.14705882 0.03846154 0.         0.2781457
#  0.25853659 0.        ]
#               precision    recall  f1-score   support
#
#            0       0.24      0.44      0.31        96
#            1       0.75      0.03      0.06        96
#            2       0.25      0.10      0.15        48
#            3       0.25      0.02      0.04        96
#            4       0.00      0.00      0.00        96
#            5       0.20      0.44      0.28        48
#            6       0.17      0.55      0.26        96
#            7       0.00      0.00      0.00        48
#
#     accuracy                           0.20       624
#    macro avg       0.23      0.20      0.14       624
# weighted avg       0.25      0.20      0.14       624
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# !pip install sktime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sktime
#   Downloading sktime-0.19.1-py3-none-any.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 64.4 MB/s eta 0:00:00
# Collecting deprecated>=1.2.13 (from sktime)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.22.4)
# Requirement already satisfied: pandas<2.1.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime) (23.1)
# Collecting scikit-base<0.5.0 (from sktime)
#   Downloading scikit_base-0.4.5-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.10.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.13->sktime) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.1.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.1.0,>=1.1.0->sktime) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.1.0,>=1.1.0->sktime) (1.16.0)
# Installing collected packages: scikit-base, deprecated, sktime
# Successfully installed deprecated-1.2.14 scikit-base-0.4.5 sktime-0.19.1

# %%
from sktime.classification.distance_based import KNeighborsTimeSeriesClassifier
clf = KNeighborsTimeSeriesClassifier()
clf.fit(X_train_100, y_train)
# Out:
# KNeighborsTimeSeriesClassifier()

# %%
# %%time
y_pred = clf.predict(X_test_100)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.27      0.26      0.26        96
#         calm       0.19      0.24      0.21        96
#      disgust       0.00      0.00      0.00        48
#      fearful       0.22      0.16      0.18        96
#        happy       0.18      0.29      0.22        96
#      neutral       0.13      0.21      0.16        48
#          sad       0.13      0.14      0.13        96
#    surprised       0.00      0.00      0.00        48
#
#     accuracy                           0.18       624
#    macro avg       0.14      0.16      0.15       624
# weighted avg       0.16      0.18      0.17       624
#
# CPU times: user 1min 38s, sys: 202 ms, total: 1min 39s
# Wall time: 1min 53s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
predict_proba_dist = clf.predict_proba(X_test)

# %%
def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
pred_probability = []
for eachArr in predict_proba_dist:
    pred_probability.append(softmax(eachArr))

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
print('ROC-AUC %s' % roc_auc_score(y_test, pred_probability, multi_class="ovr"))

# %% [markdown]
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.multivariate.classification.MultivariateClassifier.html#pyts.multivariate.classification.MultivariateClassifier
